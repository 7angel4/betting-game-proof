# %% [markdown]
# Bounding f_n(•) and h_n(•) with Mixed Integer Programming

# %%
# %run constants.ipynb
# %run gen_h.ipynb

# %%
import gurobipy as gp
from gurobipy import GRB
from itertools import repeat
import re

# %%
def var_name(*ineqs, prefix=''):
    '''
    Returns the variable name for the MIP.
    '''
    return prefix + f'{str(ineqs)}'

# %%
def extract_ineq(var):
    '''
    Extracts the inequality from the given variable's name.
    (For interpretability, we associate each indicator variable's name 
    with the inequality(s) they represent)
    '''
    match = re.findall(r'\(([^()]+)\)', var.varName)
    return sympify(match[0]) if match else None

# %%
def extract_ineqs(variables):
    '''
    Extracts inequalities from multiple variables, 
    based on their values (i.e. 1 = true, 0 = false).
    '''
    ineqs = []
    for v in variables:
        e = extract_ineq(v)
        if v.x == 1 and e is not None:  # indicator is true
            ineqs.append(e)
        elif v.x == 0:  # indicator is false
            ineqs.append(Not(And(e)))
    return ineqs

# %%
def to_gp_linexpr(sp_expr, var_map):
    '''
    Converts a sympy expression to a gurobipy linear expression,
    using the provided (sp : gp) variable mapping.
    '''
    gp_expr = gp.LinExpr()

    if isinstance(sp_expr, Add):
        for term in sp_expr.args:
            gp_expr.add(to_gp_linexpr(term, var_map))
    elif sp_expr.is_Mul:
        coeff = 1
        var = None
        for factor in sp_expr.args:
            if factor.is_number:  # sp coefficient
                coeff *= float(factor)
            elif factor in var_map:  # sp variable
                var = var_map[factor]
        if var is not None:
            gp_expr.addTerms(coeff, var)
        else:  # constant
            gp_expr.addConstant(coeff)
    elif sp_expr in var_map:  # single variable expression
        gp_expr.addTerms(1.0, var_map[sp_expr])
    elif sp_expr.is_number:   # single constant
        gp_expr.addConstant(float(sp_expr))

    return gp_expr

# %%
EPS = 1
def unify_ineq(ineq):
    '''
    Converts the given inequality to the form expr >= 0.
    '''
    lhs, rhs, op = ineq.lhs, ineq.rhs, ineq.rel_op
    # Check the inequality type and unify the format
    if op == '>=':
        # lhs >= rhs -> lhs - rhs >= 0
        return Rel(lhs - rhs, 0, '>=')
    elif op == '>':
        # lhs > rhs -> lhs - rhs > 0 => lhs - rhs >= EPS
        return Rel(lhs - rhs - EPS, 0, '>=')
    elif op == '<=':
        # lhs <= rhs -> lhs - rhs <= 0 -> rhs - lhs >= 0
        return Rel(rhs - lhs, 0, '>=')
    elif op == '<':
        # lhs < rhs -> rhs > lhs -> rhs - lhs > 0 -> rhs - lhs >= EPS
        return Rel(rhs - lhs - EPS, 0, '>=')
    else:
        raise ValueError(f"Unhandled inequality type: {op}")

# %%
def to_gp_ineq(ineq, var_map):
    '''
    Like `to_gp_linexpr`, but converts a sympy inequality to a gurobipy inequality 
    (of the form >= 0).
    '''
    return (to_gp_linexpr(unify_ineq(ineq).lhs, var_map) >= 0)

# %%
def add_ind_constr(ineq, model=None, name='ind', var_map=None):
    ''' 
    Adds indicator constraint to the model for a single inequality. 
    '''
    r = unify_ineq(ineq)  # to the form >= 0
    lhs = to_gp_linexpr(r.lhs, var_map)
    v = model.addVar(vtype=GRB.BINARY, name=name)
    model.addConstr((v == 1) >> (lhs >= 0))
    model.addConstr((v == 0) >> (lhs <= -EPS))  # lhs < 0
    return v

# %%
def add_ind_constrs(*ineqs, model=None, var_map=None):
    ''' 
    Adds variables and constraints to the model for a compound indicator 
    (i.e. may represent the and of multiple inequalities). 
    '''
    if len(ineqs) == 1:
        return (add_ind_constr(ineqs[0], 
                               name=var_name(ineqs[0], prefix='single_ind'), 
                               var_map=var_map,
                               model=model),)
    
    I = model.addVar(vtype=GRB.BINARY, 
                     name=var_name(*ineqs, prefix='main_ind'))
    component_vars = [add_ind_constr(i, 
                                     name=var_name(i, prefix='component_ind'), 
                                     var_map=var_map,
                                     model=model) for i in ineqs]
    model.addConstr(I == gp.and_(component_vars), 
                    name=var_name(*ineqs, prefix='andconstr'))
    return I, component_vars

# %%
def analyse_result(model, relax=False):
    '''
    Analyses the status of the model.
    If the model is feasible and `relax` is True, then re-optimizes the model with relaxed bounds.
    Note that if the relaxation is infeasible, then the exact model must too be infeasible
    '''
    if model.status == GRB.OPTIMAL:
        print('Optimal solution found:')
        for v in model.getVars():
            print(f"{v.varName}: {v.x}")
        print(f'Objective value:', model.objVal)
        print(f'MIPGap = |ObjBound - ObjVal|/|ObjVal|:', model.MIPGap)
    elif model.status == GRB.UNBOUNDED:
        print('The model cannot be solved because it is unbounded')
    elif model.status != GRB.INF_OR_UNBD and model.status != GRB.INFEASIBLE:
        print('Optimization was stopped with status %d' % model.status)
    else:
        # Relax the constraints and try to make the model feasible
        print('The model is infeasible')
        if relax:
            print('Relaxing the bounds')
            model.feasRelaxS(1, False, False, True)
            model.optimize()
            analyse_result(model, relax=relax)

# %%
def f_mip(n, output_file=False, analyse=True, relax=False):
    '''
    Runs MIP model to minimize f_n - thresh(n).
    If `output_file` is True, writes the model as a '.lp' file.
    If `analyse` is True, analyses the optimization results.
    '''
    # uncomment the following to collect the regions cut out (i.e. excluded) by the model
#     failed_regions = []
    
#     def extract_region(model):
#         region = []
#         variables = model.getVars()
#         sol = model.cbGetSolution(variables)
#         for v, val in zip(variables, sol):
#             # only look at the individual indicators
#             if not 'single_ind' in v.varName and not 'component_ind' in v.varName:
#                 continue
#             e = extract_ineq(v)
#             if val == 1 and e is not None:
#                 region.append(e[0])
#             elif val == 0:
#                 # indicator is false
#                 # guaranteed single inequality
#                 region.append(Not(e[0]))
#         return region
    
#     def pos_f_callback(model, where):
#         if where == GRB.Callback.MIPSOL:
#             # Capture node information
#             try:
#                 obj = model.cbGet(GRB.Callback.MIPSOL_OBJ)
#                 print("Current objective:", obj)
#                 if obj > 0:  # Node is infeasible
#                     failed_regions.append(extract_region(model))
#             except gp.GurobiError as e:
#                 print(f"Gurobi error during callback: {e}")
#             except Exception as e:
#                 print(f"Unexpected error during callback: {e}")
    
    h_xyz = read(H_XYZ_CACHE, min_n=1, max_n=n)
    h_yxz = read(H_YXZ_CACHE, min_n=1, max_n=n)
    num_pos_per_n = [len(H_XYZ[i][1]) for i in range(1,n+1)]
    num_neg_per_n = [len(H_YXZ[i][1]) for i in range(1,n+1)]
    num_pos = sum(num_pos_per_n)
    num_neg = sum(num_neg_per_n)
    
    pos_coefs = concat([repeat(j, k) for j,k in zip([coef(i) for i in range(1,n+1)], num_pos_per_n)])
    neg_coefs = concat([repeat(j, k) for j,k in zip([-coef(i) for i in range(1,n+1)], num_neg_per_n)])
    const = sum([coef(i)*(H_XYZ[i][0] - H_YXZ[i][0]) for i in range(1,n+1)])
    
    all_pos_comp_inds = concat([H_XYZ[i][1] for i in range(1,n+1)])
    all_neg_comp_inds = concat([H_YXZ[i][1] for i in range(1,n+1)])
    
    model = gp.Model(f'f_{n}(x,y,z)-thresh{n}', env=gp.Env())
    model.Params.OutputFlag = 1
    model.Params.LogToConsole = 1
    model.Params.MIPFocus = 1
    
    gx = model.addVar(lb=1, vtype='I', name='x')
    gy = model.addVar(lb=1, vtype='I', name='y')
    gz = model.addVar(lb=1, vtype='I', name='z')
    sp_to_gp = {x: gx, y: gy, z: gz}
    
    pos_inds = [add_ind_constrs(*i, model=model, var_map=sp_to_gp) \
                for i in all_pos_comp_inds]
    neg_inds = [add_ind_constrs(*i, model=model, var_map=sp_to_gp) \
                for i in all_neg_comp_inds]
    
    obj = gp.quicksum([pos_coefs[i]*pos_inds[i][0] for i in range(num_pos)]) + \
        gp.quicksum([neg_coefs[i]*neg_inds[i][0] for i in range(num_neg)]) + const - thresh(n)
    
    model.setObjective(obj, GRB.MINIMIZE)
    f_constr = model.addConstr(obj <= 0, name='non_pos_f')
    # constraints for V
    for i, ineq in enumerate(V):
        model.addConstr(to_gp_ineq(ineq, sp_to_gp), name=f'V{i}')
    
#     model.optimize(pos_f_callback)
    model.optimize()
    
    if analyse:
        analyse_result(model, relax=relax)
    
    if output_file:
        model.write(f'f_{n}(x,y,z)-thresh{n}.lp')
    
    return ((model.status == GRB.OPTIMAL and \
            model.MIPGap == 0 and \
            eval_f(n, gx.x, gy.x, gz.x) < 0), # sanity check using the x,y,z values from the model
            model)

# %%
f_mip(4, analyse=True, relax=True)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-02
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[rosetta2] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 898 columns and 360 nonzeros
# Model fingerprint: 0xedd93d96
# Model has 1543 general constraints
# Variable types: 0 continuous, 898 integer (895 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+00]
#   Objective range  [8e-04, 3e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 1e+00]
#   GenCon rhs range [1e+00, 1e+00]
#   GenCon coe range [1e+00, 2e+01]
# Presolve added 2344 rows and 1944 columns
# Presolve time: 0.02s
# Presolved: 2348 rows, 2842 columns, 7222 nonzeros
# Presolved model has 1296 SOS constraint(s)
# Variable types: 0 continuous, 2842 integer (1543 binary)
#
# Root relaxation: objective -2.375000e-01, 1327 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.23750    0  312          -   -0.23750      -     -    0s
#      0     0   -0.23750    0  312          -   -0.23750      -     -    0s
#      0     2   -0.23750    0  312          -   -0.23750      -     -    0s
#  18566    28   -0.20509   57  312          -   -0.21512      -   3.2    5s
#  58024   342 infeasible  148               -   -0.13410      -  12.2   10s
#  109586    72   -0.03380  172  104          -   -0.03380      -   9.9   15s
#
# Explored 112735 nodes (1881470 simplex iterations) in 15.64 seconds (21.85 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# The model is infeasible
# Relaxing the bounds
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[rosetta2] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[rosetta2] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 902 columns and 364 nonzeros
# Model fingerprint: 0xa9e1d0af
# Model has 4 quadratic objective terms
# Model has 1543 general constraints
# Variable types: 4 continuous, 898 integer (895 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 1e+00]
#   GenCon rhs range [1e+00, 1e+00]
#   GenCon coe range [1e+00, 2e+01]
# Presolve added 2344 rows and 1943 columns
# Presolve time: 0.02s
# Presolved: 2348 rows, 2845 columns, 7225 nonzeros
# Presolved model has 1296 SOS constraint(s)
# Presolved model has 3 quadratic objective terms
# Variable types: 3 continuous, 2842 integer (1543 binary)
# Found heuristic solution: objective 0.0108829
#
# Root relaxation: objective 0.000000e+00, 2923 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  368    0.01088    0.00000   100%     -    0s
#      0     0    0.00000    0  368    0.01088    0.00000   100%     -    0s
#      0     2    0.00000    0  368    0.01088    0.00000   100%     -    0s
# H   50    17                       0.0009621    0.00000   100%   325    0s
# H   60    11                       0.0009149    0.00000   100%   320    0s
# H  122    14                       0.0008688    0.00000   100%   253    0s
# H  168    26                       0.0008239    0.00000   100%   242    0s
# H  215    30                       0.0007802    0.00000   100%   209    0s
# H  369    52                       0.0007377    0.00000   100%   161    1s
# H  645   129                       0.0004087    0.00000   100%   117    2s
#   2070   239     cutoff   42         0.00041    0.00000   100%  58.1    5s
#   4645   310     cutoff   32         0.00041    0.00000   100%  57.5   10s
#   9168   749 infeasible  156         0.00041    0.00000   100%  55.9   15s
# *14410  2127             345       0.0002934    0.00000   100%  46.5   18s
#  17886  2811    0.00000  231   86    0.00029    0.00000   100%  41.7   20s
#  29486  4869    0.00000  283   58    0.00029    0.00000   100%  33.2   25s
#  35646  5707    0.00000  222   94    0.00029    0.00000   100%  33.9   30s
#  40979  6924 infeasible  273         0.00029    0.00000   100%  35.3   35s
#  44977  6387    0.00000   83  141    0.00029    0.00000   100%  36.4   40s
#  49762  5285    0.00000  308   29    0.00029    0.00000   100%  36.2   45s
#  59076  3354 infeasible  199         0.00029    0.00000   100%  34.9   50s
#  69166  2676 infeasible  137         0.00029    0.00000   100%  34.5   56s
#  74433  2697    0.00000  203  117    0.00029    0.00000   100%  34.4   60s
#  81700  1520 infeasible  184         0.00029    0.00000   100%  34.6   65s
#  86817  1529    0.00000  166  139    0.00029    0.00000   100%  34.9   70s
#  92580  1493 infeasible  204         0.00029    0.00000   100%  34.9   75s
#  100245  1999    0.00000  241   38    0.00029    0.00000   100%  33.6   80s
#  111157  2391    0.00018  299   28    0.00029    0.00000   100%  30.8   85s
#  121495  1591    0.00000  289   36    0.00029    0.00000   100%  28.5   90s
#  128252  3069    0.00000  326   24    0.00029    0.00000   100%  27.4   95s
#  143582  4230    0.00024  420   23    0.00029    0.00000   100%  25.0  100s
#  158284  5006    0.00000  278   44    0.00029    0.00000   100%  23.2  105s
#  168551  6213 infeasible  640         0.00029    0.00000   100%  22.1  111s
#  181343  7200 infeasible  600         0.00029    0.00000   100%  21.0  115s
#  192735  8328    0.00000  335   23    0.00029    0.00000   100%  20.1  120s
#  208352 10170    0.00000  957   68    0.00029    0.00000   100%  19.0  125s
#  225783 11112    0.00000 1070   44    0.00029    0.00000   100%  18.1  130s
#  243036 12255    0.00000  446   35    0.00029    0.00000   100%  17.2  135s
#  253293 13361    0.00000  860   20    0.00029    0.00000   100%  16.7  140s
#  269761 14718    0.00027 1072   18    0.00029    0.00000   100%  16.1  145s
#  289498 16599 infeasible 1262         0.00029    0.00000   100%  15.4  150s
#  303261 18189 infeasible  427         0.00029    0.00000   100%  14.9  155s
#  319992 20002 infeasible 1151         0.00029    0.00000   100%  14.4  160s
#  333663 21195    0.00009 1473   15    0.00029    0.00000   100%  14.0  165s
#  350389 22730 infeasible 1376         0.00029    0.00000   100%  13.6  170s
#  362030 24078    0.00012  565   11    0.00029    0.00000   100%  13.4  175s
#  379528 25423    0.00000 1481   53    0.00029    0.00000   100%  13.0  180s
#  395310 26488    0.00012  712   10    0.00029    0.00000   100%  12.7  185s
#  407252 28471    0.00014  715    8    0.00029    0.00000   100%  12.5  190s
#  427574 29762    0.00009  995   15    0.00029    0.00000   100%  12.1  195s
#  440109 30814    0.00020  424   17    0.00029    0.00000   100%  11.9  200s
#  450464 32137    0.00000 1307   67    0.00029    0.00000   100%  11.8  205s
#  467646 34476    0.00022  608   49    0.00029    0.00000   100%  11.6  210s
#  485681 36019 infeasible  916         0.00029    0.00000   100%  11.4  215s
#  501522 37689    0.00000  433   27    0.00029    0.00000   100%  11.2  220s
#  513770 39104    0.00000  317   38    0.00029    0.00000   100%  11.1  225s
#  528276 39858    0.00000  673   18    0.00029    0.00000   100%  10.9  230s
#  542866 41179    0.00027  627   15    0.00029    0.00000   100%  10.8  235s
#  556561 42567    0.00010  929   45    0.00029    0.00000   100%  10.6  240s
#  571513 43960 infeasible  408         0.00029    0.00000   100%  10.5  245s
#  589264 45374    0.00000 1387   61    0.00029    0.00000   100%  10.3  250s
#  602037 47660    0.00024  637   19    0.00029    0.00000   100%  10.2  255s
#  620870 48449    0.00000  322   24    0.00029    0.00000   100%  10.1  260s
#  634696 49617    0.00000  686  107    0.00029    0.00000   100%  10.0  265s
#  654249 51469    0.00009 1377   15    0.00029    0.00000   100%   9.9  270s
#  660493 52557    0.00020  363   20    0.00029    0.00000   100%   9.8  275s
#  677021 53974    0.00000 1299   66    0.00029    0.00000   100%   9.7  280s
#  690040 56081 infeasible  558         0.00029    0.00000   100%   9.6  285s
#  707316 57444    0.00010  768   28    0.00029    0.00000   100%   9.5  290s
#  722244 58033    0.00000  941   79    0.00029    0.00000   100%   9.4  295s
#  735393 60870    0.00007  613   17    0.00029    0.00000   100%   9.4  300s
#  755272 62196    0.00000  577   76    0.00029    0.00000   100%   9.3  305s
#  766669 62915 infeasible  393         0.00029    0.00000   100%   9.2  310s
#  781107 64146    0.00027 1013   44    0.00029    0.00000   100%   9.2  315s
#  795323 65617    0.00010  851   19    0.00029    0.00000   100%   9.1  320s
#  810379 67954    0.00000 1335   71    0.00029    0.00000   100%   9.0  325s
#  824345 69041    0.00000  641   26    0.00029    0.00000   100%   9.0  330s
#  840073 69993 infeasible 1093         0.00029    0.00000   100%   8.9  335s
#  852507 71316 infeasible  266         0.00029    0.00000   100%   8.8  340s
#  866602 72620    0.00000 1500   34    0.00029    0.00000   100%   8.8  345s
#  876724 73815 infeasible  513         0.00029    0.00000   100%   8.8  350s
#  890193 75099    0.00014 1058   10    0.00029    0.00000   100%   8.7  355s
#  907379 76749     cutoff  724         0.00029    0.00000   100%   8.7  360s
#  921067 78338    0.00000  478   29    0.00029    0.00000   100%   8.6  365s
#  934515 79687    0.00000  840   57    0.00029    0.00000   100%   8.6  370s
#  946380 80814    0.00000 1470   32    0.00029    0.00000   100%   8.5  375s
#  960912 81827    0.00000  837   41    0.00029    0.00000   100%   8.5  380s
#  974170 83006    0.00000  358   37    0.00029    0.00000   100%   8.4  385s
#  988136 84000 infeasible  870         0.00029    0.00000   100%   8.4  390s
#  999356 85462 infeasible  715         0.00029    0.00000   100%   8.4  395s
#  1008326 86558    0.00000 1541   20    0.00029    0.00000   100%   8.3  400s
#  1027316 88336    0.00000 1089   84    0.00029    0.00000   100%   8.3  405s
#  1040139 89814    0.00000  625   73    0.00029    0.00000   100%   8.3  410s
#  1055986 91613    0.00000  382   69    0.00029    0.00000   100%   8.2  415s
#  1068382 92400    0.00000 1025   62    0.00029    0.00000   100%   8.2  420s
#  1082147 93658    0.00000  417   98    0.00029    0.00000   100%   8.1  425s
#  1094124 95534    0.00000 1322   44    0.00029    0.00000   100%   8.1  430s
#  1108848 96819    0.00005  597   20    0.00029    0.00000   100%   8.1  435s
#  1122390 98526    0.00000 1211   58    0.00029    0.00000   100%   8.0  440s
#  1138026 99609    0.00000  391   96    0.00029    0.00000   100%   8.0  445s
#  1152392 101103    0.00000  762   60    0.00029    0.00000   100%   8.0  450s
#  1167072 102500    0.00000  603   34    0.00029    0.00000   100%   7.9  455s
#  1177053 103426 infeasible  383         0.00029    0.00000   100%   7.9  460s
#  1188828 104249    0.00027 1316   46    0.00029    0.00000   100%   7.9  465s
#  1199161 106255    0.00014 1517    9    0.00029    0.00000   100%   7.9  470s
#  1216736 107658    0.00000  428   99    0.00029    0.00000   100%   7.8  475s
#  1230803 108834    0.00000  397   22    0.00029    0.00000   100%   7.8  480s
#  1244221 110102    0.00000 1440   40    0.00029    0.00000   100%   7.8  485s
#  1259733 111534    0.00000  455   36    0.00029    0.00000   100%   7.8  490s
#  1271821 113090    0.00000  410   34    0.00029    0.00000   100%   7.7  495s
#  1283301 114212    0.00000  503   18    0.00029    0.00000   100%   7.7  500s
#  1295211 115518    0.00000 1398   22    0.00029    0.00000   100%   7.7  505s
#  1310040 116329    0.00000 1072   51    0.00029    0.00000   100%   7.7  510s
#  1323334 117638    0.00014 1442   14    0.00029    0.00000   100%   7.6  515s
#  1331886 118328    0.00027 1139   30    0.00029    0.00000   100%   7.6  520s
#  1341294 120576 infeasible 1227         0.00029    0.00000   100%   7.6  525s
#  1359201 121884 infeasible  434         0.00029    0.00000   100%   7.6  530s
#  1374488 122473 infeasible  909         0.00029    0.00000   100%   7.5  535s
#  1391748 123847    0.00010  691   19    0.00029    0.00000   100%   7.5  540s
#  1402416 124495    0.00000 1006   71    0.00029    0.00000   100%   7.5  545s
#  1419488 125646    0.00027  751   49    0.00029    0.00000   100%   7.5  550s
#  1432485 126937    0.00000  536   40    0.00029    0.00000   100%   7.5  555s
#  1446077 128092 infeasible  404         0.00029    0.00000   100%   7.4  560s
#  1459498 129710    0.00027 1178   25    0.00029    0.00000   100%   7.4  565s
#  1477117 131778    0.00000  297   26    0.00029    0.00000   100%   7.4  570s
#  1491481 133226    0.00000  778   32    0.00029    0.00000   100%   7.4  575s
#  1506791 134672 infeasible  406         0.00029    0.00000   100%   7.3  580s
#  1518820 136182 infeasible  405         0.00029    0.00000   100%   7.3  585s
#  1524618 136763    0.00000  795   29    0.00029    0.00000   100%   7.3  590s
#  1542122 138241 infeasible 1478         0.00029    0.00000   100%   7.3  595s
#  1556476 138839    0.00000 1427   42    0.00029    0.00000   100%   7.3  600s
#  1567667 139899    0.00020  628    4    0.00029    0.00000   100%   7.3  605s
#  1583442 136454 infeasible  518         0.00029    0.00000   100%   7.2  610s
#  1600325 141090    0.00022 1160   10    0.00029    0.00000   100%   7.2  615s
#  1616899 149068    0.00016 1312   18    0.00029    0.00000   100%   7.1  620s
#  1638303 154971 infeasible  671         0.00029    0.00000   100%   7.0  625s
#  1658264 155268 infeasible 1129         0.00029    0.00000   100%   7.0  630s
#  1678355 142250    0.00004 1404   56    0.00029    0.00000  99.0%   6.9  635s
#  1694081 147765    0.00012 1194   55    0.00029    0.00000  99.0%   6.8  640s
#  1700746 151126    0.00014 1446   46    0.00029    0.00000  99.0%   6.8  645s
#  1713859 154575 infeasible 1493         0.00029    0.00000  99.0%   6.8  650s
#  1727292 142433 infeasible  528         0.00029    0.00001  97.9%   6.7  655s
#  1787708 104126 infeasible  707         0.00029    0.00010  64.6%   6.6  660s
#  1867912 44148 infeasible  385         0.00029    0.00018  40.0%   6.3  665s
#  1920112 37274    0.00020 1562   23    0.00029    0.00020  32.8%   6.2  670s
#  1966964 36771    0.00020  862   48    0.00029    0.00020  32.8%   6.0  675s
#  2019518 31743    0.00022 1414   49    0.00029    0.00022  25.2%   5.9  680s
#  2076052 27680 infeasible 1435         0.00029    0.00022  25.2%   5.8  685s
#  2130343 23255     cutoff  909         0.00029    0.00024  17.2%   5.7  690s
#
# Explored 2169047 nodes (12123851 simplex iterations) in 692.55 seconds (715.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 0.000293424 0.000408689 0.000737692 ... 0.0108829
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.934242112483e-04, best bound 2.934242112483e-04, gap 0.0000%
# Optimal solution found:
# x: 20.0
# y: 21.0
# z: 7.0
# single_ind(3*x <= y,): 0.0
# single_ind(x <= 3*z,): 1.0
# single_ind(x <= y - z,): 0.0
# single_ind(x <= 2*z,): 0.0
# single_ind(7*x <= y,): 0.0
# main_ind(5*x <= 3*y, y < 3*x): -0.0
# component_ind(5*x <= 3*y,): 0.0
# component_ind(y < 3*x,): 1.0
# main_ind(3*x <= y + z, y < 3*x): -0.0
# component_ind(3*x <= y + z,): 0.0
# component_ind(y < 3*x,): 1.0
# single_ind(3*x <= y + z,): 0.0
# single_ind(2*x <= 3*z,): 0.0
# single_ind(3*x <= y - z,): 0.0
# single_ind(3*x <= y + 3*z,): 0.0
# single_ind(x <= 2*z,): 0.0
# main_ind(2*x <= y + 2*z, x < 3*z): -0.0
# component_ind(2*x <= y + 2*z,): 0.0
# component_ind(x < 3*z,): 1.0
# single_ind(3*x <= 5*z,): 0.0
# single_ind(y < 2*z,): 0.0
# single_ind(x <= -y + 3*z,): 0.0
# single_ind(3*z < x,): 0.0
# main_ind(x <= 7*z, 3*z < x): -0.0
# component_ind(x <= 7*z,): 1.0
# component_ind(3*z < x,): 0.0
# single_ind(x <= y - z,): 0.0
# main_ind(x <= 5*z, 2*z < y): 1.0
# component_ind(x <= 5*z,): 1.0
# component_ind(2*z < y,): 1.0
# single_ind(3*x <= y - z,): 0.0
# main_ind(2*x <= y - z, x < 2*z): -0.0
# component_ind(2*x <= y - z,): 0.0
# component_ind(x < 2*z,): 0.0
# main_ind(x <= 3*y - 3*z, y - z < x): 1.0
# component_ind(x <= 3*y - 3*z,): 1.0
# component_ind(y - z < x,): 1.0
# single_ind(y - z < x,): 1.0
# main_ind(x <= 2*y - 2*z, y < 3*z): -0.0
# component_ind(x <= 2*y - 2*z,): 1.0
# component_ind(y < 3*z,): 0.0
# single_ind(x <= -y + 3*z,): 0.0
# single_ind(2*z < x,): 1.0
# main_ind(x <= 6*z, 2*z < x): 1.0
# component_ind(x <= 6*z,): 1.0
# component_ind(2*z < x,): 1.0
# single_ind(x <= y - 3*z,): 0.0
# main_ind(x <= 4*z, 3*z < y): -0.0
# component_ind(x <= 4*z,): 1.0
# component_ind(3*z < y,): 0.0
# single_ind(15*x <= y,): 0.0
# main_ind(13*x <= 3*y, y < 7*x): -0.0
# component_ind(13*x <= 3*y,): 0.0
# component_ind(y < 7*x,): 1.0
# main_ind(7*x <= y + z, y < 7*x): -0.0
# component_ind(7*x <= y + z,): 0.0
# component_ind(y < 7*x,): 1.0
# single_ind(7*x <= y + z,): 0.0
# single_ind(7*x <= y - z,): 0.0
# main_ind(11*x <= 5*y, y < 3*x): -0.0
# component_ind(11*x <= 5*y,): 0.0
# component_ind(y < 3*x,): 1.0
# main_ind(6*x <= 2*y + z, y < 3*x): -0.0
# component_ind(6*x <= 2*y + z,): 0.0
# component_ind(y < 3*x,): 1.0
# main_ind(2*x <= y, y < 3*x, 3*x < y + z): -0.0
# component_ind(2*x <= y,): 0.0
# component_ind(y < 3*x,): 1.0
# component_ind(3*x < y + z,): 0.0
# main_ind(9*x <= 3*y + z, y < 3*x): -0.0
# component_ind(9*x <= 3*y + z,): 0.0
# component_ind(y < 3*x,): 1.0
# main_ind(9*x <= 7*y, 3*y < 5*x): -0.0
# component_ind(9*x <= 7*y,): 0.0
# component_ind(3*y < 5*x,): 1.0
# main_ind(5*x <= 3*y + z, 3*y < 5*x): -0.0
# component_ind(5*x <= 3*y + z,): 0.0
# component_ind(3*y < 5*x,): 1.0
# main_ind(7*x <= 5*y, y < 3*x, 2*y - z < 2*x): -0.0
# component_ind(7*x <= 5*y,): 0.0
# component_ind(y < 3*x,): 1.0
# component_ind(2*y - z < 2*x,): 1.0
# main_ind(5*x <= 3*y + z, y + z < 3*x): -0.0
# component_ind(5*x <= 3*y + z,): 0.0
# component_ind(y + z < 3*x,): 1.0
# main_ind(3*x <= y + 3*z, y + z < 3*x): -0.0
# component_ind(3*x <= y + 3*z,): 0.0
# component_ind(y + z < 3*x,): 1.0
# main_ind(5*x <= 3*y - z, y < 3*x): -0.0
# component_ind(5*x <= 3*y - z,): 0.0
# component_ind(y < 3*x,): 1.0
# main_ind(3*x <= y + 2*z, y < 3*x, 2*x < 2*y - z): -0.0
# component_ind(3*x <= y + 2*z,): 0.0
# component_ind(y < 3*x,): 1.0
# component_ind(2*x < 2*y - z,): 0.0
# main_ind(4*x <= 3*y, y < 2*x, y - z < x): -0.0
# component_ind(4*x <= 3*y,): 0.0
# component_ind(y < 2*x,): 1.0
# component_ind(y - z < x,): 1.0
# single_ind(3*y - 3*z <= x,): 0.0
# single_ind(7*x <= y + 3*z,): 0.0
# main_ind(5*x <= y + 2*z, 2*x < 3*z): -0.0
# component_ind(5*x <= y + 2*z,): 0.0
# component_ind(2*x < 3*z,): 0.0
# main_ind(5*x <= 3*y + z, y + z < 3*x): -0.0
# component_ind(5*x <= 3*y + z,): 0.0
# component_ind(y + z < 3*x,): 1.0
# main_ind(3*x <= y + 3*z, y + z < 3*x): -0.0
# component_ind(3*x <= y + 3*z,): 0.0
# component_ind(y + z < 3*x,): 1.0
# main_ind(4*x <= 2*y + z, y - 2*z < x): -0.0
# component_ind(4*x <= 2*y + z,): 0.0
# component_ind(y - 2*z < x,): 1.0
# single_ind(x <= -y + 3*z,): 0.0
# main_ind(3*x <= y + 3*z, 3*z < 2*x): -0.0
# component_ind(3*x <= y + 3*z,): 0.0
# component_ind(3*z < 2*x,): 1.0
# main_ind(2*x <= 7*z, 3*z < 2*x): 1.0
# component_ind(2*x <= 7*z,): 1.0
# component_ind(3*z < 2*x,): 1.0
# single_ind(3*x <= y - z,): 0.0
# main_ind(2*x <= 5*z, x < y - 2*z): -0.0
# component_ind(2*x <= 5*z,): -0.0
# component_ind(x < y - 2*z,): 0.0
# single_ind(7*x <= y - z,): 0.0
# main_ind(5*x <= 3*y - 3*z, y - z < 3*x): -0.0
# component_ind(5*x <= 3*y - 3*z,): 0.0
# component_ind(y - z < 3*x,): 1.0
# main_ind(3*x <= y + z, y - z < 3*x): -0.0
# component_ind(3*x <= y + z,): 0.0
# component_ind(y - z < 3*x,): 1.0
# main_ind(2*x <= y - z, y - 3*z < x): -0.0
# component_ind(2*x <= y - z,): 0.0
# component_ind(y - 3*z < x,): 1.0
# single_ind(3*x <= y + z,): 0.0
# main_ind(x <= 3*z, x < y - z): -0.0
# component_ind(x <= 3*z,): 1.0
# component_ind(x < y - z,): 0.0
# single_ind(3*x <= y - 3*z,): 0.0
# main_ind(x <= 2*z, x < y - 3*z): -0.0
# component_ind(x <= 2*z,): 0.0
# component_ind(x < y - 3*z,): 0.0
# single_ind(7*x <= y + 7*z,): 0.0
# single_ind(2*x <= 3*z,): 0.0
# main_ind(5*x <= y + 5*z, x < 2*z): -0.0
# component_ind(5*x <= y + 5*z,): 0.0
# component_ind(x < 2*z,): 0.0
# single_ind(3*x <= 4*z,): 0.0
# main_ind(5*x <= 3*y + 5*z, y + 3*z < 3*x): -0.0
# component_ind(5*x <= 3*y + 5*z,): 0.0
# component_ind(y + 3*z < 3*x,): 1.0
# main_ind(3*x <= y + 5*z, y + 3*z < 3*x): -0.0
# component_ind(3*x <= y + 5*z,): 0.0
# component_ind(y + 3*z < 3*x,): 1.0
# main_ind(2*x <= y + 2*z, y - z < x): -0.0
# component_ind(2*x <= y + 2*z,): 0.0
# component_ind(y - z < x,): 1.0
# single_ind(x <= -y + 3*z,): 0.0
# main_ind(3*x <= y + 5*z, 2*z < x): -0.0
# component_ind(3*x <= y + 5*z,): 0.0
# component_ind(2*z < x,): 1.0
# main_ind(x <= 4*z, 2*z < x): 1.0
# component_ind(x <= 4*z,): 1.0
# component_ind(2*z < x,): 1.0
# single_ind(3*x <= y + z,): 0.0
# main_ind(x <= 3*z, x < y - z): -0.0
# component_ind(x <= 3*z,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(6*x <= y + 6*z, x < 3*z): -0.0
# component_ind(6*x <= y + 6*z,): 0.0
# component_ind(x < 3*z,): 1.0
# single_ind(5*x <= 7*z,): 0.0
# main_ind(4*x <= y + 4*z, 3*x < 5*z): -0.0
# component_ind(4*x <= y + 4*z,): 0.0
# component_ind(3*x < 5*z,): 0.0
# single_ind(7*x <= 9*z,): 0.0
# main_ind(y + 2*z < 2*x, x < 3*z): 1.0
# component_ind(y + 2*z < 2*x,): 1.0
# component_ind(x < 3*z,): 1.0
# main_ind(3*x <= y + 5*z, y + 2*z < 2*x, x < 3*z): -0.0
# component_ind(3*x <= y + 5*z,): 0.0
# component_ind(y + 2*z < 2*x,): 1.0
# component_ind(x < 3*z,): 1.0
# single_ind(x < -y + 3*z,): 0.0
# single_ind(3*x <= -y + 5*z,): 0.0
# main_ind(3*x <= y + 5*z, 5*z < 3*x, x < 3*z): -0.0
# component_ind(3*x <= y + 5*z,): 0.0
# component_ind(5*z < 3*x,): 1.0
# component_ind(x < 3*z,): 1.0
# main_ind(5*x <= 11*z, 5*z < 3*x): -0.0
# component_ind(5*x <= 11*z,): 0.0
# component_ind(5*z < 3*x,): 1.0
# main_ind(x <= y - z, x < 3*z): -0.0
# component_ind(x <= y - z,): 0.0
# component_ind(x < 3*z,): 1.0
# main_ind(x <= 2*z, -y + 3*z < x): -0.0
# component_ind(x <= 2*z,): 0.0
# component_ind(-y + 3*z < x,): 1.0
# main_ind(3*x <= 2*y + 3*z, y < 2*z): -0.0
# component_ind(3*x <= 2*y + 3*z,): 1.0
# component_ind(y < 2*z,): 0.0
# single_ind(2*x <= -y + 4*z,): 0.0
# single_ind(x < -y + 3*z,): 0.0
# single_ind(3*x <= -y + 5*z,): 0.0
# main_ind(-y + 3*z < x, y < 2*z): -0.0
# component_ind(-y + 3*z < x,): 1.0
# component_ind(y < 2*z,): 0.0
# main_ind(x <= -3*y + 7*z, -y + 3*z < x): -0.0
# component_ind(x <= -3*y + 7*z,): 0.0
# component_ind(-y + 3*z < x,): 1.0
# single_ind(y < 2*z,): 0.0
# single_ind(x <= -2*y + 5*z,): 0.0
# main_ind(3*x <= y + 9*z, 3*z < x): -0.0
# component_ind(3*x <= y + 9*z,): 1.0
# component_ind(3*z < x,): 0.0
# main_ind(x <= 5*z, 3*z < x): -0.0
# component_ind(x <= 5*z,): 1.0
# component_ind(3*z < x,): 0.0
# main_ind(2*x <= y + 6*z, 3*z < x, x < 7*z): -0.0
# component_ind(2*x <= y + 6*z,): 1.0
# component_ind(3*z < x,): 0.0
# component_ind(x < 7*z,): 1.0
# main_ind(3*x <= 13*z, 3*z < x): -0.0
# component_ind(3*x <= 13*z,): 1.0
# component_ind(3*z < x,): 0.0
# main_ind(3*z < x, y < 4*z): -0.0
# component_ind(3*z < x,): 0.0
# component_ind(y < 4*z,): 1.0
# main_ind(x <= -y + 7*z, 3*z < x, y < 4*z): -0.0
# component_ind(x <= -y + 7*z,): 1.0
# component_ind(3*z < x,): 0.0
# component_ind(y < 4*z,): 1.0
# single_ind(7*z < x,): 0.0
# main_ind(x <= 15*z, 7*z < x): -0.0
# component_ind(x <= 15*z,): 1.0
# component_ind(7*z < x,): 0.0
# main_ind(x <= y - z, 3*z < x, 4*z < y): -0.0
# component_ind(x <= y - z,): 0.0
# component_ind(3*z < x,): 0.0
# component_ind(4*z < y,): 0.0
# main_ind(x <= 11*z, 3*z < x, 4*z < y): -0.0
# component_ind(x <= 11*z,): 1.0
# component_ind(3*z < x,): 0.0
# component_ind(4*z < y,): 0.0
# single_ind(3*x <= y + z,): 0.0
# main_ind(x <= 3*z, x < y - z): -0.0
# component_ind(x <= 3*z,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(2*x <= y, x < 5*z): -0.0
# component_ind(2*x <= y,): 0.0
# component_ind(x < 5*z,): 1.0
# main_ind(3*x <= 7*z, 2*z < y): -0.0
# component_ind(3*x <= 7*z,): 0.0
# component_ind(2*z < y,): 1.0
# main_ind(x <= 3*y - 5*z, y - z < x): 1.0
# component_ind(x <= 3*y - 5*z,): 1.0
# component_ind(y - z < x,): 1.0
# main_ind(y - z < x, 2*z < y): 1.0
# component_ind(y - z < x,): 1.0
# component_ind(2*z < y,): 1.0
# main_ind(x <= 2*y - 3*z, y < 6*z): 1.0
# component_ind(x <= 2*y - 3*z,): 1.0
# component_ind(y < 6*z,): 1.0
# main_ind(x <= -y + 7*z, 2*z < y): 1.0
# component_ind(x <= -y + 7*z,): 1.0
# component_ind(2*z < y,): 1.0
# main_ind(5*z < x, 2*z < y): -0.0
# component_ind(5*z < x,): 0.0
# component_ind(2*z < y,): 1.0
# main_ind(x <= 13*z, 5*z < x, 2*z < y): -0.0
# component_ind(x <= 13*z,): 1.0
# component_ind(5*z < x,): 0.0
# component_ind(2*z < y,): 1.0
# single_ind(x <= y - 5*z,): 0.0
# main_ind(x <= 9*z, 6*z < y): -0.0
# component_ind(x <= 9*z,): 1.0
# component_ind(6*z < y,): 0.0
# single_ind(7*x <= y - z,): 0.0
# main_ind(5*x <= 3*y - 3*z, y - z < 3*x): -0.0
# component_ind(5*x <= 3*y - 3*z,): 0.0
# component_ind(y - z < 3*x,): 1.0
# main_ind(3*x <= y + z, y - z < 3*x): -0.0
# component_ind(3*x <= y + z,): 0.0
# component_ind(y - z < 3*x,): 1.0
# main_ind(2*x <= y - z, y - 3*z < x): -0.0
# component_ind(2*x <= y - z,): 0.0
# component_ind(y - 3*z < x,): 1.0
# single_ind(3*x <= y + z,): 0.0
# main_ind(x <= 3*z, x < y - z): -0.0
# component_ind(x <= 3*z,): 1.0
# component_ind(x < y - z,): 0.0
# single_ind(3*x <= y - 3*z,): 0.0
# main_ind(x <= 2*z, x < y - 3*z): -0.0
# component_ind(x <= 2*z,): 0.0
# component_ind(x < y - 3*z,): 0.0
# main_ind(6*x <= y - z, x < 2*z): -0.0
# component_ind(6*x <= y - z,): 0.0
# component_ind(x < 2*z,): 0.0
# main_ind(2*x <= 3*y - 3*z, y - z < 2*x, x < 2*z): -0.0
# component_ind(2*x <= 3*y - 3*z,): 1.0
# component_ind(y - z < 2*x,): 1.0
# component_ind(x < 2*z,): 0.0
# main_ind(3*x <= y + z, y - z < 2*x, x < 2*z): -0.0
# component_ind(3*x <= y + z,): 0.0
# component_ind(y - z < 2*x,): 1.0
# component_ind(x < 2*z,): 0.0
# main_ind(3*x <= y + z, x < 2*z): -0.0
# component_ind(3*x <= y + z,): 0.0
# component_ind(x < 2*z,): 0.0
# single_ind(5*x <= 6*z,): 0.0
# main_ind(x <= y - 3*z, x < 2*z): -0.0
# component_ind(x <= y - 3*z,): 0.0
# component_ind(x < 2*z,): 0.0
# main_ind(3*x <= 5*y - 5*z, y - z < x): 1.0
# component_ind(3*x <= 5*y - 5*z,): 1.0
# component_ind(y - z < x,): 1.0
# main_ind(y - z < x, x < 3*y - 3*z): 1.0
# component_ind(y - z < x,): 1.0
# component_ind(x < 3*y - 3*z,): 1.0
# main_ind(x <= 2*y - 2*z, y - z < x): 1.0
# component_ind(x <= 2*y - 2*z,): 1.0
# component_ind(y - z < x,): 1.0
# main_ind(3*x <= 3*y - z, y - z < x): -0.0
# component_ind(3*x <= 3*y - z,): 0.0
# component_ind(y - z < x,): 1.0
# main_ind(x <= 7*y - 7*z, 3*y - 3*z < x): -0.0
# component_ind(x <= 7*y - 7*z,): 1.0
# component_ind(3*y - 3*z < x,): 0.0
# single_ind(3*y - 3*z < x,): 0.0
# main_ind(x <= 5*y - 5*z, y - z < x, y < 2*z): -0.0
# component_ind(x <= 5*y - 5*z,): 1.0
# component_ind(y - z < x,): 1.0
# component_ind(y < 2*z,): 0.0
# single_ind(x <= -y + 3*z,): 0.0
# main_ind(x <= 3*y - 5*z, y - z < x): 1.0
# component_ind(x <= 3*y - 5*z,): 1.0
# component_ind(y - z < x,): 1.0
# main_ind(y - z < x, 2*z < y): 1.0
# component_ind(y - z < x,): 1.0
# component_ind(2*z < y,): 1.0
# main_ind(3*x <= 2*y - 2*z, y < 3*z): -0.0
# component_ind(3*x <= 2*y - 2*z,): 0.0
# component_ind(y < 3*z,): -0.0
# main_ind(x <= 6*y - 6*z, 2*y - 2*z < x, y < 3*z): -0.0
# component_ind(x <= 6*y - 6*z,): 1.0
# component_ind(2*y - 2*z < x,): 0.0
# component_ind(y < 3*z,): 0.0
# main_ind(2*y - 2*z < x, y < 3*z): -0.0
# component_ind(2*y - 2*z < x,): 0.0
# component_ind(y < 3*z,): -0.0
# main_ind(x <= 4*y - 4*z, 3*y < 5*z): -0.0
# component_ind(x <= 4*y - 4*z,): 1.0
# component_ind(3*y < 5*z,): 0.0
# single_ind(x <= -3*y + 5*z,): 0.0
# main_ind(-y + 3*z < x, y < 3*z): -0.0
# component_ind(-y + 3*z < x,): 1.0
# component_ind(y < 3*z,): 0.0
# main_ind(x <= -3*y + 9*z, -y + 3*z < x): -0.0
# component_ind(x <= -3*y + 9*z,): 0.0
# component_ind(-y + 3*z < x,): 1.0
# main_ind(x <= 3*y - 5*z, y < 3*z): -0.0
# component_ind(x <= 3*y - 5*z,): 1.0
# component_ind(y < 3*z,): 0.0
# main_ind(x <= -2*y + 6*z, 5*z < 3*y): -0.0
# component_ind(x <= -2*y + 6*z,): 0.0
# component_ind(5*z < 3*y,): 1.0
# main_ind(3*x <= y + 5*z, 2*z < x): -0.0
# component_ind(3*x <= y + 5*z,): 0.0
# component_ind(2*z < x,): 1.0
# main_ind(x <= 4*z, 2*z < x): 1.0
# component_ind(x <= 4*z,): 1.0
# component_ind(2*z < x,): 1.0
# main_ind(2*x <= y + 3*z, 2*z < x, x < 6*z): 1.0
# component_ind(2*x <= y + 3*z,): 1.0
# component_ind(2*z < x,): 1.0
# component_ind(x < 6*z,): 1.0
# main_ind(3*x <= 10*z, 2*z < x): 1.0
# component_ind(3*x <= 10*z,): 1.0
# component_ind(2*z < x,): 1.0
# main_ind(2*z < x, y < 5*z): 1.0
# component_ind(2*z < x,): 1.0
# component_ind(y < 5*z,): 1.0
# main_ind(x <= -y + 7*z, 2*z < x, y < 5*z): 1.0
# component_ind(x <= -y + 7*z,): 1.0
# component_ind(2*z < x,): 1.0
# component_ind(y < 5*z,): 1.0
# single_ind(6*z < x,): 0.0
# main_ind(x <= 14*z, 6*z < x): -0.0
# component_ind(x <= 14*z,): 1.0
# component_ind(6*z < x,): 0.0
# main_ind(x <= y - 3*z, 2*z < x, 5*z < y): -0.0
# component_ind(x <= y - 3*z,): 0.0
# component_ind(2*z < x,): 1.0
# component_ind(5*z < y,): 0.0
# main_ind(x <= 10*z, 2*z < x, 5*z < y): -0.0
# component_ind(x <= 10*z,): 1.0
# component_ind(2*z < x,): 1.0
# component_ind(5*z < y,): 0.0
# single_ind(3*x <= y - 3*z,): 0.0
# main_ind(x <= 2*z, x < y - 3*z): -0.0
# component_ind(x <= 2*z,): 0.0
# component_ind(x < y - 3*z,): 0.0
# main_ind(2*x <= y - 3*z, x < 4*z): -0.0
# component_ind(2*x <= y - 3*z,): 0.0
# component_ind(x < 4*z,): 1.0
# main_ind(3*x <= 4*z, 3*z < y): -0.0
# component_ind(3*x <= 4*z,): 0.0
# component_ind(3*z < y,): -0.0
# main_ind(x <= 3*y - 9*z, y - 3*z < x): -0.0
# component_ind(x <= 3*y - 9*z,): 0.0
# component_ind(y - 3*z < x,): 1.0
# main_ind(y - 3*z < x, 3*z < y): -0.0
# component_ind(y - 3*z < x,): 1.0
# component_ind(3*z < y,): 0.0
# main_ind(x <= 2*y - 6*z, y < 7*z): -0.0
# component_ind(x <= 2*y - 6*z,): 0.0
# component_ind(y < 7*z,): 1.0
# main_ind(x <= -y + 7*z, 3*z < y, 3*z < y): -0.0
# component_ind(x <= -y + 7*z,): 1.0
# component_ind(3*z < y,): -0.0
# component_ind(3*z < y,): 0.0
# main_ind(4*z < x, 3*z < y): -0.0
# component_ind(4*z < x,): 0.0
# component_ind(3*z < y,): -0.0
# main_ind(x <= 12*z, 4*z < x, 3*z < y): -0.0
# component_ind(x <= 12*z,): 1.0
# component_ind(4*z < x,): 0.0
# component_ind(3*z < y,): -0.0
# single_ind(x <= y - 7*z,): 0.0
# main_ind(x <= 8*z, 7*z < y): -0.0
# component_ind(x <= 8*z,): 1.0
# component_ind(7*z < y,): 0.0
# single_ind(y <= 3*x,): 1.0
# single_ind(y - z <= x,): 1.0
# single_ind(y - z <= x,): 1.0
# single_ind(y <= 3*z,): 1.0
# single_ind(y <= 2*z,): 0.0
# single_ind(3*y <= 5*x,): 1.0
# single_ind(2*y - z <= 2*x,): 1.0
# main_ind(y <= 2*x, y - z < x): 1.0
# component_ind(y <= 2*x,): 1.0
# component_ind(y - z < x,): 1.0
# single_ind(3*y - z <= 3*x,): 1.0
# main_ind(y <= 7*x, 3*x < y): 0.0
# component_ind(y <= 7*x,): 1.0
# component_ind(3*x < y,): 0.0
# main_ind(y - z <= 3*x, 3*x < y): 0.0
# component_ind(y - z <= 3*x,): 1.0
# component_ind(3*x < y,): 0.0
# main_ind(y - z <= 3*x, x < y - z): 0.0
# component_ind(y - z <= 3*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - 3*z <= x, x < y - z): 0.0
# component_ind(y - 3*z <= x,): 1.0
# component_ind(x < y - z,): 0.0
# single_ind(y + z <= 3*x,): 1.0
# single_ind(y - 2*z <= x,): 1.0
# single_ind(3*y - 3*z <= x,): 0.0
# single_ind(y <= 2*z,): 0.0
# single_ind(2*y - 2*z <= x,): 0.0
# single_ind(3*y <= 5*z,): 0.0
# main_ind(y - z <= 3*x, x < y - z): 0.0
# component_ind(y - z <= 3*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - 3*z <= x, x < y - z): 0.0
# component_ind(y - 3*z <= x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - z <= 2*x, x < 2*z): 0.0
# component_ind(y - z <= 2*x,): 1.0
# component_ind(x < 2*z,): 0.0
# single_ind(x <= -y + 3*z,): 0.0
# main_ind(y - 3*z <= x, 3*z < y): 0.0
# component_ind(y - 3*z <= x,): 1.0
# component_ind(3*z < y,): 0.0
# main_ind(y <= 7*z, 3*z < y): 0.0
# component_ind(y <= 7*z,): 1.0
# component_ind(3*z < y,): 0.0
# main_ind(y <= 5*z, 2*z < x): 1.0
# component_ind(y <= 5*z,): 1.0
# component_ind(2*z < x,): 1.0
# single_ind(y + 3*z <= 3*x,): 1.0
# single_ind(y - z <= x,): 1.0
# main_ind(y + 2*z <= 2*x, x < 3*z): 1.0
# component_ind(y + 2*z <= 2*x,): 1.0
# component_ind(x < 3*z,): 1.0
# single_ind(x <= -y + 3*z,): 0.0
# main_ind(y - z <= x, 2*z < y): 1.0
# component_ind(y - z <= x,): 1.0
# component_ind(2*z < y,): 1.0
# main_ind(y <= 6*z, 2*z < y): 1.0
# component_ind(y <= 6*z,): 1.0
# component_ind(2*z < y,): 1.0
# main_ind(y <= 4*z, 3*z < x): 0.0
# component_ind(y <= 4*z,): 1.0
# component_ind(3*z < x,): 0.0
# single_ind(7*y <= 9*x,): 1.0
# single_ind(4*y - z <= 4*x,): 1.0
# main_ind(5*y <= 7*x, 2*y - z < 2*x): 1.0
# component_ind(5*y <= 7*x,): 1.0
# component_ind(2*y - z < 2*x,): 1.0
# single_ind(6*y - z <= 6*x,): 1.0
# main_ind(5*y <= 11*x, 5*x < 3*y): 0.0
# component_ind(5*y <= 11*x,): 1.0
# component_ind(5*x < 3*y,): 0.0
# main_ind(3*y - z <= 5*x, 5*x < 3*y): 0.0
# component_ind(3*y - z <= 5*x,): 1.0
# component_ind(5*x < 3*y,): 0.0
# main_ind(3*y - z <= 5*x, 2*x < 2*y - z): 0.0
# component_ind(3*y - z <= 5*x,): 1.0
# component_ind(2*x < 2*y - z,): 0.0
# main_ind(2*y - 3*z <= 2*x, 2*x < 2*y - z): 0.0
# component_ind(2*y - 3*z <= 2*x,): 1.0
# component_ind(2*x < 2*y - z,): 0.0
# single_ind(3*y + z <= 5*x,): 1.0
# single_ind(y - z <= x,): 1.0
# main_ind(3*y <= 4*x, y - z < x): 1.0
# component_ind(3*y <= 4*x,): 1.0
# component_ind(y - z < x,): 1.0
# single_ind(5*y - z <= 5*x,): 1.0
# main_ind(2*y <= 3*x, 3*y - z < 3*x): 1.0
# component_ind(2*y <= 3*x,): 1.0
# component_ind(3*y - z < 3*x,): 1.0
# single_ind(7*y - z <= 7*x,): 1.0
# main_ind(3*y - z <= 5*x, 3*x < 3*y - z, y - z < x): 0.0
# component_ind(3*y - z <= 5*x,): 1.0
# component_ind(3*x < 3*y - z,): 0.0
# component_ind(y - z < x,): 1.0
# main_ind(5*y - 3*z <= 5*x, 3*x < 3*y - z): 0.0
# component_ind(5*y - 3*z <= 5*x,): 1.0
# component_ind(3*x < 3*y - z,): 0.0
# main_ind(y + z <= 3*x, y - z < x): 1.0
# component_ind(y + z <= 3*x,): 1.0
# component_ind(y - z < x,): 1.0
# single_ind(2*y - z <= 2*x,): 1.0
# main_ind(3*y <= 13*x, 3*x < y): 0.0
# component_ind(3*y <= 13*x,): 1.0
# component_ind(3*x < y,): 0.0
# main_ind(2*y - z <= 6*x, 3*x < y): 0.0
# component_ind(2*y - z <= 6*x,): 1.0
# component_ind(3*x < y,): 0.0
# main_ind(y <= 5*x, 3*x < y, y - z < 3*x): 0.0
# component_ind(y <= 5*x,): 1.0
# component_ind(3*x < y,): 0.0
# component_ind(y - z < 3*x,): 1.0
# main_ind(3*y - z <= 9*x, 3*x < y): 0.0
# component_ind(3*y - z <= 9*x,): 1.0
# component_ind(3*x < y,): 0.0
# main_ind(y <= 15*x, 7*x < y): 0.0
# component_ind(y <= 15*x,): 1.0
# component_ind(7*x < y,): 0.0
# main_ind(y - z <= 7*x, 7*x < y): 0.0
# component_ind(y - z <= 7*x,): 1.0
# component_ind(7*x < y,): 0.0
# main_ind(y - z <= 7*x, 3*x < y - z): 0.0
# component_ind(y - z <= 7*x,): 1.0
# component_ind(3*x < y - z,): 0.0
# main_ind(y - 3*z <= 3*x, 3*x < y - z): 0.0
# component_ind(y - 3*z <= 3*x,): 1.0
# component_ind(3*x < y - z,): 0.0
# main_ind(y + z <= 7*x, 3*x < y): 0.0
# component_ind(y + z <= 7*x,): 1.0
# component_ind(3*x < y,): 0.0
# main_ind(y - 2*z <= 3*x, 3*x < y): 0.0
# component_ind(y - 2*z <= 3*x,): 1.0
# component_ind(3*x < y,): 0.0
# main_ind(3*y - 3*z <= 5*x, x < y - z): 0.0
# component_ind(3*y - 3*z <= 5*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - 2*z <= x, x < y - z, x < y - z): 0.0
# component_ind(y - 2*z <= x,): 1.0
# component_ind(x < y - z,): 0.0
# component_ind(x < y - z,): 0.0
# main_ind(y - z <= 2*x, x < y - z, y - 3*z < x): 0.0
# component_ind(y - z <= 2*x,): 1.0
# component_ind(x < y - z,): 0.0
# component_ind(y - 3*z < x,): 1.0
# main_ind(3*y - 5*z <= 3*x, x < y - z): 0.0
# component_ind(3*y - 5*z <= 3*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - z <= 7*x, 3*x < y - z): 0.0
# component_ind(y - z <= 7*x,): 1.0
# component_ind(3*x < y - z,): 0.0
# main_ind(y - 3*z <= 3*x, 3*x < y - z): 0.0
# component_ind(y - 3*z <= 3*x,): 1.0
# component_ind(3*x < y - z,): 0.0
# main_ind(y - 3*z <= 3*x, x < y - 3*z): 0.0
# component_ind(y - 3*z <= 3*x,): 1.0
# component_ind(x < y - 3*z,): 0.0
# main_ind(y - 7*z <= x, x < y - 3*z): 0.0
# component_ind(y - 7*z <= x,): 1.0
# component_ind(x < y - 3*z,): 0.0
# main_ind(y + z <= 3*x, x < y - z): 0.0
# component_ind(y + z <= 3*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - 5*z <= x, x < y - z): 0.0
# component_ind(y - 5*z <= x,): 1.0
# component_ind(x < y - z,): 0.0
# single_ind(3*y + z <= 5*x,): 1.0
# single_ind(y - z <= x,): 1.0
# main_ind(2*y + z <= 4*x, y - 2*z < x): 1.0
# component_ind(2*y + z <= 4*x,): 1.0
# component_ind(y - 2*z < x,): 1.0
# single_ind(3*y - 2*z <= 3*x,): 1.0
# main_ind(y + 3*z <= 7*x, 3*x < y + z): 0.0
# component_ind(y + 3*z <= 7*x,): 1.0
# component_ind(3*x < y + z,): 0.0
# main_ind(y - z <= 3*x, 3*x < y + z): 0.0
# component_ind(y - z <= 3*x,): 1.0
# component_ind(3*x < y + z,): 0.0
# main_ind(y + 2*z <= 5*x, 2*x < 3*z): 0.0
# component_ind(y + 2*z <= 5*x,): 1.0
# component_ind(2*x < 3*z,): 0.0
# single_ind(x <= -y + 3*z,): 0.0
# main_ind(y - z <= 3*x, x < y - 2*z): 0.0
# component_ind(y - z <= 3*x,): 1.0
# component_ind(x < y - 2*z,): 0.0
# main_ind(y - 6*z <= x, x < y - 2*z): 0.0
# component_ind(y - 6*z <= x,): 1.0
# component_ind(x < y - 2*z,): 0.0
# single_ind(y + 3*z <= 3*x,): 1.0
# main_ind(y - 4*z <= x, 3*z < 2*x): 1.0
# component_ind(y - 4*z <= x,): 1.0
# component_ind(3*z < 2*x,): 1.0
# single_ind(7*y - 7*z <= x,): 0.0
# main_ind(2*y <= 3*z, 3*y - 3*z < x): 0.0
# component_ind(2*y <= 3*z,): 0.0
# component_ind(3*y - 3*z < x,): 0.0
# single_ind(5*y - 5*z <= x,): 0.0
# single_ind(3*y <= 4*z,): 0.0
# main_ind(5*y - 5*z <= 3*x, x < 3*y - 3*z): 0.0
# component_ind(5*y - 5*z <= 3*x,): 0.0
# component_ind(x < 3*y - 3*z,): 1.0
# main_ind(3*y - 5*z <= x, x < 3*y - 3*z): 0.0
# component_ind(3*y - 5*z <= x,): 0.0
# component_ind(x < 3*y - 3*z,): 1.0
# single_ind(2*y - 2*z <= x,): 0.0
# single_ind(x <= -y + 3*z,): 0.0
# main_ind(3*y - 5*z <= x, 2*z < y): 0.0
# component_ind(3*y - 5*z <= x,): 0.0
# component_ind(2*z < y,): 1.0
# main_ind(y <= 4*z, 2*z < y, y - z < x): 1.0
# component_ind(y <= 4*z,): 1.0
# component_ind(2*z < y,): 1.0
# component_ind(y - z < x,): 1.0
# single_ind(6*y - 6*z <= x,): 0.0
# single_ind(5*y <= 7*z,): 0.0
# single_ind(4*y - 4*z <= x,): 0.0
# single_ind(7*y <= 9*z,): 0.0
# main_ind(2*y - 2*z <= 3*x, x < 2*y - 2*z, y < 3*z): 0.0
# component_ind(2*y - 2*z <= 3*x,): 1.0
# component_ind(x < 2*y - 2*z,): 1.0
# component_ind(y < 3*z,): 0.0
# main_ind(3*y - 5*z <= x, x < 2*y - 2*z): 0.0
# component_ind(3*y - 5*z <= x,): 0.0
# component_ind(x < 2*y - 2*z,): 1.0
# main_ind(y - z <= x, x < -y + 3*z): 0.0
# component_ind(y - z <= x,): 1.0
# component_ind(x < -y + 3*z,): 0.0
# single_ind(x <= -3*y + 5*z,): 0.0
# main_ind(3*y - 5*z <= x, 5*z < 3*y): 0.0
# component_ind(3*y - 5*z <= x,): 0.0
# component_ind(5*z < 3*y,): 1.0
# main_ind(5*y <= 11*z, 5*z < 3*y): 0.0
# component_ind(5*y <= 11*z,): 0.0
# component_ind(5*z < 3*y,): 1.0
# main_ind(y <= 2*z, -y + 3*z < x): 0.0
# component_ind(y <= 2*z,): 0.0
# component_ind(-y + 3*z < x,): 1.0
# main_ind(3*y - 3*z <= 5*x, x < y - z): 0.0
# component_ind(3*y - 3*z <= 5*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - 2*z <= x, x < y - z, x < y - z): 0.0
# component_ind(y - 2*z <= x,): 1.0
# component_ind(x < y - z,): 0.0
# component_ind(x < y - z,): 0.0
# main_ind(y - z <= 2*x, x < y - z, y - 3*z < x): 0.0
# component_ind(y - z <= 2*x,): 1.0
# component_ind(x < y - z,): 0.0
# component_ind(y - 3*z < x,): 1.0
# main_ind(3*y - 5*z <= 3*x, x < y - z): 0.0
# component_ind(3*y - 5*z <= 3*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - z <= 7*x, 3*x < y - z): 0.0
# component_ind(y - z <= 7*x,): 1.0
# component_ind(3*x < y - z,): 0.0
# main_ind(y - 3*z <= 3*x, 3*x < y - z): 0.0
# component_ind(y - 3*z <= 3*x,): 1.0
# component_ind(3*x < y - z,): 0.0
# main_ind(y - 3*z <= 3*x, x < y - 3*z): 0.0
# component_ind(y - 3*z <= 3*x,): 1.0
# component_ind(x < y - 3*z,): 0.0
# main_ind(y - 7*z <= x, x < y - 3*z): 0.0
# component_ind(y - 7*z <= x,): 1.0
# component_ind(x < y - 3*z,): 0.0
# main_ind(y + z <= 3*x, x < y - z): 0.0
# component_ind(y + z <= 3*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - 5*z <= x, x < y - z): 0.0
# component_ind(y - 5*z <= x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(3*y - 3*z <= 2*x, x < 2*z): 0.0
# component_ind(3*y - 3*z <= 2*x,): 0.0
# component_ind(x < 2*z,): 0.0
# single_ind(x <= -2*y + 4*z,): 0.0
# main_ind(y - z <= x, x < -y + 3*z): 0.0
# component_ind(y - z <= x,): 1.0
# component_ind(x < -y + 3*z,): 0.0
# single_ind(x <= -3*y + 5*z,): 0.0
# main_ind(y - z <= 6*x, 2*x < y - z, x < 2*z): 0.0
# component_ind(y - z <= 6*x,): 1.0
# component_ind(2*x < y - z,): 0.0
# component_ind(x < 2*z,): 0.0
# main_ind(y - 3*z <= x, 2*x < y - z, x < 2*z): 0.0
# component_ind(y - 3*z <= x,): 1.0
# component_ind(2*x < y - z,): 0.0
# component_ind(x < 2*z,): 0.0
# main_ind(y - 3*z <= x, -y + 3*z < x, x < 2*z): 0.0
# component_ind(y - 3*z <= x,): 1.0
# component_ind(-y + 3*z < x,): 1.0
# component_ind(x < 2*z,): 0.0
# main_ind(3*x <= -y + 7*z, -y + 3*z < x): 0.0
# component_ind(3*x <= -y + 7*z,): 0.0
# component_ind(-y + 3*z < x,): 1.0
# main_ind(y + z <= 3*x, x < 2*z): 0.0
# component_ind(y + z <= 3*x,): 1.0
# component_ind(x < 2*z,): 0.0
# single_ind(2*x <= -y + 5*z,): 0.0
# main_ind(3*y - 9*z <= x, 3*z < y): 0.0
# component_ind(3*y - 9*z <= x,): 1.0
# component_ind(3*z < y,): 0.0
# main_ind(y <= 5*z, 3*z < y, y - 3*z < x): 0.0
# component_ind(y <= 5*z,): 1.0
# component_ind(3*z < y,): 0.0
# component_ind(y - 3*z < x,): 1.0
# main_ind(2*y - 6*z <= x, 3*z < y): 0.0
# component_ind(2*y - 6*z <= x,): 1.0
# component_ind(3*z < y,): 0.0
# main_ind(3*y <= 13*z, 3*z < y): 0.0
# component_ind(3*y <= 13*z,): 1.0
# component_ind(3*z < y,): 0.0
# main_ind(y - 3*z <= 3*x, x < y - 3*z): 0.0
# component_ind(y - 3*z <= 3*x,): 1.0
# component_ind(x < y - 3*z,): 0.0
# main_ind(y - 7*z <= x, x < y - 3*z): 0.0
# component_ind(y - 7*z <= x,): 1.0
# component_ind(x < y - 3*z,): 0.0
# main_ind(y - 3*z <= 2*x, 3*z < y, x < 4*z): 0.0
# component_ind(y - 3*z <= 2*x,): 1.0
# component_ind(3*z < y,): 0.0
# component_ind(x < 4*z,): 1.0
# main_ind(x <= -y + 7*z, 3*z < y, 3*z < y): 0.0
# component_ind(x <= -y + 7*z,): 1.0
# component_ind(3*z < y,): 0.0
# component_ind(3*z < y,): 0.0
# main_ind(y - 7*z <= x, 7*z < y): 0.0
# component_ind(y - 7*z <= x,): 1.0
# component_ind(7*z < y,): 0.0
# main_ind(y <= 15*z, 7*z < y): 0.0
# component_ind(y <= 15*z,): 1.0
# component_ind(7*z < y,): 0.0
# main_ind(y <= 11*z, 3*z < y, 4*z < x): 0.0
# component_ind(y <= 11*z,): 1.0
# component_ind(3*z < y,): 0.0
# component_ind(4*z < x,): 0.0
# main_ind(3*y <= 7*z, 2*z < x): 0.0
# component_ind(3*y <= 7*z,): 0.0
# component_ind(2*z < x,): 1.0
# single_ind(y + 5*z <= 3*x,): 1.0
# main_ind(y - 3*z <= x, 2*z < x): 1.0
# component_ind(y - 3*z <= x,): 1.0
# component_ind(2*z < x,): 1.0
# main_ind(y + 3*z <= 2*x, x < 6*z): 0.0
# component_ind(y + 3*z <= 2*x,): 0.0
# component_ind(x < 6*z,): 1.0
# main_ind(x <= -y + 7*z, 2*z < x): 1.0
# component_ind(x <= -y + 7*z,): 1.0
# component_ind(2*z < x,): 1.0
# main_ind(y - 3*z <= x, 5*z < y, 2*z < x): 0.0
# component_ind(y - 3*z <= x,): 1.0
# component_ind(5*z < y,): 0.0
# component_ind(2*z < x,): 1.0
# main_ind(y <= 13*z, 5*z < y, 2*z < x): 0.0
# component_ind(y <= 13*z,): 1.0
# component_ind(5*z < y,): 0.0
# component_ind(2*z < x,): 1.0
# main_ind(y <= 9*z, 6*z < x): 0.0
# component_ind(y <= 9*z,): 1.0
# component_ind(6*z < x,): 0.0
# single_ind(5*y <= 6*z,): 0.0
# single_ind(3*y + 5*z <= 5*x,): 1.0
# main_ind(y + 2*z <= 2*x, y - z < x): 1.0
# component_ind(y + 2*z <= 2*x,): 1.0
# component_ind(y - z < x,): 1.0
# main_ind(y + 7*z <= 7*x, 3*x < y + 3*z): 0.0
# component_ind(y + 7*z <= 7*x,): 1.0
# component_ind(3*x < y + 3*z,): 0.0
# main_ind(y + z <= 3*x, 3*x < y + 3*z): 0.0
# component_ind(y + z <= 3*x,): 1.0
# component_ind(3*x < y + 3*z,): 0.0
# main_ind(y + 5*z <= 5*x, x < 2*z): 0.0
# component_ind(y + 5*z <= 5*x,): 1.0
# component_ind(x < 2*z,): 0.0
# single_ind(x <= -y + 3*z,): 0.0
# main_ind(y + z <= 3*x, x < y - z): 0.0
# component_ind(y + z <= 3*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - 5*z <= x, x < y - z): 0.0
# component_ind(y - 5*z <= x,): 1.0
# component_ind(x < y - z,): 0.0
# single_ind(y + 5*z <= 3*x,): 1.0
# main_ind(y - 3*z <= x, 2*z < x): 1.0
# component_ind(y - 3*z <= x,): 1.0
# component_ind(2*z < x,): 1.0
# main_ind(y + 6*z <= 6*x, 2*x < y + 2*z, x < 3*z): 0.0
# component_ind(y + 6*z <= 6*x,): 1.0
# component_ind(2*x < y + 2*z,): 0.0
# component_ind(x < 3*z,): 1.0
# main_ind(y - z <= x, 2*x < y + 2*z, x < 3*z): 0.0
# component_ind(y - z <= x,): 1.0
# component_ind(2*x < y + 2*z,): 0.0
# component_ind(x < 3*z,): 1.0
# main_ind(y + 4*z <= 4*x, 3*x < 5*z): 0.0
# component_ind(y + 4*z <= 4*x,): 1.0
# component_ind(3*x < 5*z,): 0.0
# single_ind(3*x <= -y + 5*z,): 0.0
# main_ind(y - z <= x, -y + 3*z < x, x < 3*z): 1.0
# component_ind(y - z <= x,): 1.0
# component_ind(-y + 3*z < x,): 1.0
# component_ind(x < 3*z,): 1.0
# main_ind(3*x <= -y + 9*z, -y + 3*z < x): 0.0
# component_ind(3*x <= -y + 9*z,): 0.0
# component_ind(-y + 3*z < x,): 1.0
# main_ind(y + 5*z <= 3*x, x < 3*z): 1.0
# component_ind(y + 5*z <= 3*x,): 1.0
# component_ind(x < 3*z,): 1.0
# main_ind(2*x <= -y + 6*z, 5*z < 3*x): 0.0
# component_ind(2*x <= -y + 6*z,): 0.0
# component_ind(5*z < 3*x,): 1.0
# main_ind(3*y - 5*z <= x, 2*z < y): 0.0
# component_ind(3*y - 5*z <= x,): 0.0
# component_ind(2*z < y,): 1.0
# main_ind(y <= 4*z, 2*z < y, y - z < x): 1.0
# component_ind(y <= 4*z,): 1.0
# component_ind(2*z < y,): 1.0
# component_ind(y - z < x,): 1.0
# main_ind(2*y - 3*z <= x, 2*z < y): 0.0
# component_ind(2*y - 3*z <= x,): 0.0
# component_ind(2*z < y,): 1.0
# main_ind(3*y <= 10*z, 2*z < y): 1.0
# component_ind(3*y <= 10*z,): 1.0
# component_ind(2*z < y,): 1.0
# main_ind(y + z <= 3*x, x < y - z): 0.0
# component_ind(y + z <= 3*x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y - 5*z <= x, x < y - z): 0.0
# component_ind(y - 5*z <= x,): 1.0
# component_ind(x < y - z,): 0.0
# main_ind(y <= 2*x, 2*z < y, x < 5*z): 1.0
# component_ind(y <= 2*x,): 1.0
# component_ind(2*z < y,): 1.0
# component_ind(x < 5*z,): 1.0
# main_ind(x <= -y + 7*z, 2*z < y): 1.0
# component_ind(x <= -y + 7*z,): 1.0
# component_ind(2*z < y,): 1.0
# main_ind(y - 5*z <= x, 6*z < y): 0.0
# component_ind(y - 5*z <= x,): 1.0
# component_ind(6*z < y,): 0.0
# main_ind(y <= 14*z, 6*z < y): 0.0
# component_ind(y <= 14*z,): 1.0
# component_ind(6*z < y,): 0.0
# main_ind(y <= 10*z, 2*z < y, 5*z < x): 0.0
# component_ind(y <= 10*z,): 1.0
# component_ind(2*z < y,): 1.0
# component_ind(5*z < x,): 0.0
# single_ind(y + 9*z <= 3*x,): 0.0
# main_ind(y - z <= x, 3*z < x): 0.0
# component_ind(y - z <= x,): 1.0
# component_ind(3*z < x,): 0.0
# main_ind(y + 6*z <= 2*x, x < 7*z): 0.0
# component_ind(y + 6*z <= 2*x,): 0.0
# component_ind(x < 7*z,): 1.0
# main_ind(x <= -y + 7*z, 3*z < x): 0.0
# component_ind(x <= -y + 7*z,): 1.0
# component_ind(3*z < x,): 0.0
# main_ind(y - z <= x, 4*z < y, 3*z < x): 0.0
# component_ind(y - z <= x,): 1.0
# component_ind(4*z < y,): 0.0
# component_ind(3*z < x,): 0.0
# main_ind(y <= 12*z, 4*z < y, 3*z < x): 0.0
# component_ind(y <= 12*z,): 1.0
# component_ind(4*z < y,): 0.0
# component_ind(3*z < x,): 0.0
# main_ind(y <= 8*z, 7*z < x): 0.0
# component_ind(y <= 8*z,): 1.0
# component_ind(7*z < x,): 0.0
# ArtN_non_pos_f: 0.017129629629629647
# ArtP_V0: 0.0
# ArtP_V1: 0.0
# ArtP_V2: 0.0
# Objective value: 0.00029342421124828593
# MIPGap = |ObjBound - ObjVal|/|ObjVal|: 0.0

# %% [markdown]
# # LB on h_n(x,y,z) - h_n(y,x,z)

# %%
def h_mip(n, output_file=False, print_result=True):
    '''
    Like `f_mip`, but runs MIP model to minimize h_n(x,y,z) - h_n(y,x,z).
    '''
    h_xyz = read(H_XYZ_CACHE, min_n=1, max_n=n)
    h_yxz = read(H_YXZ_CACHE, min_n=1, max_n=n)
    
    all_pos_comp_inds = concat([H_XYZ[i][1] for i in range(1,n+1)])
    all_neg_comp_inds = concat([H_YXZ[i][1] for i in range(1,n+1)])
    
    model = gp.Model(f'h_{n}(x,y,z)-h_{n}(y,x,z)', env=gp.Env())
    model.Params.OutputFlag = 1
    model.Params.LogToConsole = 1
    model.Params.MIPFocus = 1
    
    gx = model.addVar(lb=1, vtype='I', name='x')
    gy = model.addVar(lb=1, vtype='I', name='y')
    gz = model.addVar(lb=1, vtype='I', name='z')
    sp_to_gp = {x: gx, y: gy, z: gz}
    
    pos_inds = [add_ind_constrs(*i, model=model, var_map=sp_to_gp) for i in H_XYZ[n][1]]
    neg_inds = [add_ind_constrs(*i, model=model, var_map=sp_to_gp) for i in H_YXZ[n][1]]
    const = H_XYZ[n][0] - H_YXZ[n][0]
    
    obj = coef(n) * (gp.quicksum([i[0] for i in pos_inds]) - gp.quicksum([i[0] for i in neg_inds]) + const)
    
    model.setObjective(obj, GRB.MINIMIZE)
    # constraints for V
#     model.addConstr(gz <= gx - 1, name='V1')
#     model.addConstr(gx <= gy - 1, name='V2')
    for i, ineq in enumerate(V):
        model.addConstr(to_gp_ineq(ineq, sp_to_gp), name=f'V{i}')
    
    model.optimize()
    
    if print_result:
        print(analyse_result(model))
    
    if output_file:
        model.write(f'h_{n}(x,y,z)-h_{n}(y,x,z).lp')
    
    return (model.status == GRB.OPTIMAL and model.MIPGap == 0), model

# %%
h_mip(4, print_result=False)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-02
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[rosetta2] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 785 columns and 5 nonzeros
# Model fingerprint: 0x6e4bd36c
# Model has 1342 general constraints
# Variable types: 0 continuous, 785 integer (782 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [8e-04, 8e-04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#   GenCon rhs range [1e+00, 1e+00]
#   GenCon coe range [1e+00, 2e+01]
# Presolve added 2040 rows and 1680 columns
# Presolve time: 0.01s
# Presolved: 2043 rows, 2465 columns, 5989 nonzeros
# Presolved model has 1120 SOS constraint(s)
# Variable types: 0 continuous, 2465 integer (1342 binary)
# Found heuristic solution: objective 0.0061728
# Found heuristic solution: objective -0.0007716
# Found heuristic solution: objective -0.0015432
# Found heuristic solution: objective -0.0038580
#
# Root relaxation: objective -1.134259e-01, 1147 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.11343    0  271   -0.00386   -0.11343  2840%     -    0s
#      0     0   -0.11343    0  271   -0.00386   -0.11343  2840%     -    0s
#      0     0   -0.11343    0  234   -0.00386   -0.11343  2840%     -    0s
#      0     0   -0.11343    0  234   -0.00386   -0.11343  2840%     -    0s
# H    0     0                      -0.0108025   -0.11343   950%     -    0s
#      0     2   -0.11343    0  234   -0.01080   -0.11343   950%     -    0s
# * 1802   673             232      -0.0123457   -0.10880   781%   5.3    1s
# H 1918   728                      -0.0146605   -0.10880   642%   5.1    1s
# H 1959   728                      -0.0154321   -0.10880   605%   5.5    1s
# H 2884   899                      -0.0162037   -0.10880   571%   7.4    1s
# H 3706   906                      -0.0169753   -0.10880   541%   6.7    2s
# *16463  6872             241      -0.0192901   -0.10031   420%   9.3    4s
#  24782  9164 infeasible   81        -0.01929   -0.09645   400%  11.6    5s
# *35509  9040             239      -0.0200617   -0.07099   254%  12.4    6s
#  63964  6358 infeasible  204        -0.02006   -0.03935  96.2%  13.5   10s
# *69831  4941             238      -0.0216049   -0.03395  57.1%  13.9   11s
#
# Explored 79242 nodes (1133116 simplex iterations) in 12.63 seconds (16.46 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: -0.0216049 -0.0200617 -0.0192901 ... -0.00385802
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.160493827160e-02, best bound -2.160493827160e-02, gap 0.0000%
# [<gurobi.Var x (value 23.0)>,
#  <gurobi.Var y (value 29.0)>,
#  <gurobi.Var z (value 4.0)>,
#  <gurobi.Var single_ind(15*x <= y,) (value -0.0)>,
#  <gurobi.Var main_ind(13*x <= 3*y, y < 7*x) (value -0.0)>,
#  <gurobi.Var component_ind(13*x <= 3*y,) (value 0.0)>,
#  <gurobi.Var component_ind(y < 7*x,) (value 1.0)>,
#  <gurobi.Var main_ind(7*x <= y + z, y < 7*x) (value -0.0)>,
#  <gurobi.Var component_ind(7*x <= y + z,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 7*x,) (value 1.0)>,
#  <gurobi.Var single_ind(7*x <= y + z,) (value -0.0)>,
#  <gurobi.Var single_ind(7*x <= y - z,) (value -0.0)>,
#  <gurobi.Var main_ind(11*x <= 5*y, y < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(11*x <= 5*y,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(6*x <= 2*y + z, y < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(6*x <= 2*y + z,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*x <= y, y < 3*x, 3*x < y + z) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= y,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y + z,) (value -0.0)>,
#  <gurobi.Var main_ind(9*x <= 3*y + z, y < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(9*x <= 3*y + z,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(9*x <= 7*y, 3*y < 5*x) (value -0.0)>,
#  <gurobi.Var component_ind(9*x <= 7*y,) (value -0.0)>,
#  <gurobi.Var component_ind(3*y < 5*x,) (value 1.0)>,
#  <gurobi.Var main_ind(5*x <= 3*y + z, 3*y < 5*x) (value -0.0)>,
#  <gurobi.Var component_ind(5*x <= 3*y + z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*y < 5*x,) (value 1.0)>,
#  <gurobi.Var main_ind(7*x <= 5*y, y < 3*x, 2*y - z < 2*x) (value -0.0)>,
#  <gurobi.Var component_ind(7*x <= 5*y,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*y - z < 2*x,) (value -0.0)>,
#  <gurobi.Var main_ind(5*x <= 3*y + z, y + z < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(5*x <= 3*y + z,) (value -0.0)>,
#  <gurobi.Var component_ind(y + z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= y + 3*z, y + z < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 3*z,) (value -0.0)>,
#  <gurobi.Var component_ind(y + z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(5*x <= 3*y - z, y < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(5*x <= 3*y - z,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= y + 2*z, y < 3*x, 2*x < 2*y - z) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 2*z,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*x < 2*y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(4*x <= 3*y, y < 2*x, y - z < x) (value -0.0)>,
#  <gurobi.Var component_ind(4*x <= 3*y,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value -0.0)>,
#  <gurobi.Var single_ind(3*y - 3*z <= x,) (value -0.0)>,
#  <gurobi.Var single_ind(7*x <= y + 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(5*x <= y + 2*z, 2*x < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(5*x <= y + 2*z,) (value -0.0)>,
#  <gurobi.Var component_ind(2*x < 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(5*x <= 3*y + z, y + z < 3*x) (value 0.0)>,
#  <gurobi.Var component_ind(5*x <= 3*y + z,) (value 0.0)>,
#  <gurobi.Var component_ind(y + z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= y + 3*z, y + z < 3*x) (value 0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(y + z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(4*x <= 2*y + z, y - 2*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(4*x <= 2*y + z,) (value -0.0)>,
#  <gurobi.Var component_ind(y - 2*z < x,) (value 1.0)>,
#  <gurobi.Var single_ind(x <= -y + 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*x <= y + 3*z, 3*z < 2*x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 3*z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*z < 2*x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*x <= 7*z, 3*z < 2*x) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= 7*z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*z < 2*x,) (value 1.0)>,
#  <gurobi.Var single_ind(3*x <= y - z,) (value -0.0)>,
#  <gurobi.Var main_ind(2*x <= 5*z, x < y - 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= 5*z,) (value -0.0)>,
#  <gurobi.Var component_ind(x < y - 2*z,) (value -0.0)>,
#  <gurobi.Var single_ind(7*x <= y - z,) (value 0.0)>,
#  <gurobi.Var main_ind(5*x <= 3*y - 3*z, y - z < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(5*x <= 3*y - 3*z,) (value -0.0)>,
#  <gurobi.Var component_ind(y - z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= y + z, y - z < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + z,) (value -0.0)>,
#  <gurobi.Var component_ind(y - z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*x <= y - z, y - 3*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= y - z,) (value -0.0)>,
#  <gurobi.Var component_ind(y - 3*z < x,) (value 1.0)>,
#  <gurobi.Var single_ind(3*x <= y + z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= 3*z, x < y - z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 3*z,) (value -0.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var single_ind(3*x <= y - 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 2*z, x < y - 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 2*z,) (value -0.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value -0.0)>,
#  <gurobi.Var single_ind(7*x <= y + 7*z,) (value -0.0)>,
#  <gurobi.Var single_ind(2*x <= 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(5*x <= y + 5*z, x < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(5*x <= y + 5*z,) (value -0.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value -0.0)>,
#  <gurobi.Var single_ind(3*x <= 4*z,) (value -0.0)>,
#  <gurobi.Var main_ind(5*x <= 3*y + 5*z, y + 3*z < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(5*x <= 3*y + 5*z,) (value -0.0)>,
#  <gurobi.Var component_ind(y + 3*z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= y + 5*z, y + 3*z < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 5*z,) (value -0.0)>,
#  <gurobi.Var component_ind(y + 3*z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*x <= y + 2*z, y - z < x) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= y + 2*z,) (value -0.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value -0.0)>,
#  <gurobi.Var single_ind(x <= -y + 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(3*x <= y + 5*z, 2*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 5*z,) (value -0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 4*z, 2*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 4*z,) (value -0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var single_ind(3*x <= y + z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 3*z, x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(x <= 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(6*x <= y + 6*z, x < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(6*x <= y + 6*z,) (value -0.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value -0.0)>,
#  <gurobi.Var single_ind(5*x <= 7*z,) (value -0.0)>,
#  <gurobi.Var main_ind(4*x <= y + 4*z, 3*x < 5*z) (value -0.0)>,
#  <gurobi.Var component_ind(4*x <= y + 4*z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*x < 5*z,) (value -0.0)>,
#  <gurobi.Var single_ind(7*x <= 9*z,) (value -0.0)>,
#  <gurobi.Var main_ind(y + 2*z < 2*x, x < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(y + 2*z < 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*x <= y + 5*z, y + 2*z < 2*x, x < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 5*z,) (value -0.0)>,
#  <gurobi.Var component_ind(y + 2*z < 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value -0.0)>,
#  <gurobi.Var single_ind(x < -y + 3*z,) (value -0.0)>,
#  <gurobi.Var single_ind(3*x <= -y + 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*x <= y + 5*z, 5*z < 3*x, x < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 5*z,) (value -0.0)>,
#  <gurobi.Var component_ind(5*z < 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(5*x <= 11*z, 5*z < 3*x) (value -0.0)>,
#  <gurobi.Var component_ind(5*x <= 11*z,) (value -0.0)>,
#  <gurobi.Var component_ind(5*z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= y - z, x < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= y - z,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 2*z, -y + 3*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 2*z,) (value -0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= 2*y + 3*z, y < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= 2*y + 3*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 2*z,) (value -0.0)>,
#  <gurobi.Var single_ind(2*x <= -y + 4*z,) (value -0.0)>,
#  <gurobi.Var single_ind(x < -y + 3*z,) (value 0.0)>,
#  <gurobi.Var single_ind(3*x <= -y + 5*z,) (value 0.0)>,
#  <gurobi.Var main_ind(-y + 3*z < x, y < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 2*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= -3*y + 7*z, -y + 3*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= -3*y + 7*z,) (value -0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var single_ind(y < 2*z,) (value -0.0)>,
#  <gurobi.Var single_ind(x <= -2*y + 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*x <= y + 9*z, 3*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 9*z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 5*z, 3*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 5*z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*x <= y + 6*z, 3*z < x, x < 7*z) (value 1.0)>,
#  <gurobi.Var component_ind(2*x <= y + 6*z,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 7*z,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= 13*z, 3*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= 13*z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*z < x, y < 4*z) (value -0.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 4*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= -y + 7*z, 3*z < x, y < 4*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= -y + 7*z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 4*z,) (value -0.0)>,
#  <gurobi.Var single_ind(7*z < x,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 15*z, 7*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 15*z,) (value 1.0)>,
#  <gurobi.Var component_ind(7*z < x,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= y - z, 3*z < x, 4*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(x <= y - z,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(4*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 11*z, 3*z < x, 4*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(x <= 11*z,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(4*z < y,) (value 1.0)>,
#  <gurobi.Var single_ind(3*x <= y + z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= 3*z, x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(x <= 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(2*x <= y, x < 5*z) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= y,) (value -0.0)>,
#  <gurobi.Var component_ind(x < 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*x <= 7*z, 2*z < y) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= 7*z,) (value -0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 3*y - 5*z, y - z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 3*y - 5*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value -0.0)>,
#  <gurobi.Var main_ind(y - z < x, 2*z < y) (value -0.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value -0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 2*y - 3*z, y < 6*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 2*y - 3*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 6*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= -y + 7*z, 2*z < y) (value -0.0)>,
#  <gurobi.Var component_ind(x <= -y + 7*z,) (value -0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(5*z < x, 2*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(5*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 13*z, 5*z < x, 2*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(x <= 13*z,) (value 1.0)>,
#  <gurobi.Var component_ind(5*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var single_ind(x <= y - 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 9*z, 6*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(x <= 9*z,) (value 1.0)>,
#  <gurobi.Var component_ind(6*z < y,) (value 1.0)>,
#  <gurobi.Var single_ind(7*x <= y - z,) (value 0.0)>,
#  <gurobi.Var main_ind(5*x <= 3*y - 3*z, y - z < 3*x) (value 0.0)>,
#  <gurobi.Var component_ind(5*x <= 3*y - 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(y - z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= y + z, y - z < 3*x) (value 0.0)>,
#  <gurobi.Var component_ind(3*x <= y + z,) (value 0.0)>,
#  <gurobi.Var component_ind(y - z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*x <= y - z, y - 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(2*x <= y - z,) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z < x,) (value 1.0)>,
#  <gurobi.Var single_ind(3*x <= y + z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= 3*z, x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(x <= 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var single_ind(3*x <= y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= 2*z, x < y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(x <= 2*z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(6*x <= y - z, x < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(6*x <= y - z,) (value -0.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value -0.0)>,
#  <gurobi.Var main_ind(2*x <= 3*y - 3*z, y - z < 2*x, x < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= 3*y - 3*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value 0.0)>,
#  <gurobi.Var main_ind(3*x <= y + z, y - z < 2*x, x < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + z,) (value -0.0)>,
#  <gurobi.Var component_ind(y - z < 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*x <= y + z, x < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= y + z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value -0.0)>,
#  <gurobi.Var single_ind(5*x <= 6*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= y - 3*z, x < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= y - 3*z,) (value -0.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value 0.0)>,
#  <gurobi.Var main_ind(3*x <= 5*y - 5*z, y - z < x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= 5*y - 5*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var main_ind(y - z < x, x < 3*y - 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 3*y - 3*z,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 2*y - 2*z, y - z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 2*y - 2*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value -0.0)>,
#  <gurobi.Var main_ind(3*x <= 3*y - z, y - z < x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= 3*y - z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 7*y - 7*z, 3*y - 3*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 7*y - 7*z,) (value 1.0)>,
#  <gurobi.Var component_ind(3*y - 3*z < x,) (value -0.0)>,
#  <gurobi.Var single_ind(3*y - 3*z < x,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 5*y - 5*z, y - z < x, y < 2*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 5*y - 5*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 2*z,) (value 0.0)>,
#  <gurobi.Var single_ind(x <= -y + 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= 3*y - 5*z, y - z < x) (value 0.0)>,
#  <gurobi.Var component_ind(x <= 3*y - 5*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var main_ind(y - z < x, 2*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= 2*y - 2*z, y < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= 2*y - 2*z,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= 6*y - 6*z, 2*y - 2*z < x, y < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 6*y - 6*z,) (value 1.0)>,
#  <gurobi.Var component_ind(2*y - 2*z < x,) (value -0.0)>,
#  <gurobi.Var component_ind(y < 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(2*y - 2*z < x, y < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(2*y - 2*z < x,) (value 0.0)>,
#  <gurobi.Var component_ind(y < 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 4*y - 4*z, 3*y < 5*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 4*y - 4*z,) (value 1.0)>,
#  <gurobi.Var component_ind(3*y < 5*z,) (value -0.0)>,
#  <gurobi.Var single_ind(x <= -3*y + 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(-y + 3*z < x, y < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= -3*y + 9*z, -y + 3*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= -3*y + 9*z,) (value 0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 3*y - 5*z, y < 3*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 3*y - 5*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= -2*y + 6*z, 5*z < 3*y) (value -0.0)>,
#  <gurobi.Var component_ind(x <= -2*y + 6*z,) (value -0.0)>,
#  <gurobi.Var component_ind(5*z < 3*y,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= y + 5*z, 2*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(3*x <= y + 5*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 4*z, 2*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(x <= 4*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*x <= y + 3*z, 2*z < x, x < 6*z) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= y + 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 6*z,) (value 1.0)>,
#  <gurobi.Var main_ind(3*x <= 10*z, 2*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= 10*z,) (value -0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*z < x, y < 5*z) (value -0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= -y + 7*z, 2*z < x, y < 5*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= -y + 7*z,) (value -0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 5*z,) (value -0.0)>,
#  <gurobi.Var single_ind(6*z < x,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 14*z, 6*z < x) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 14*z,) (value 1.0)>,
#  <gurobi.Var component_ind(6*z < x,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= y - 3*z, 2*z < x, 5*z < y) (value -0.0)>,
#  <gurobi.Var component_ind(x <= y - 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(5*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 10*z, 2*z < x, 5*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(x <= 10*z,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(5*z < y,) (value 1.0)>,
#  <gurobi.Var single_ind(3*x <= y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= 2*z, x < y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(x <= 2*z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(2*x <= y - 3*z, x < 4*z) (value -0.0)>,
#  <gurobi.Var component_ind(2*x <= y - 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 4*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*x <= 4*z, 3*z < y) (value -0.0)>,
#  <gurobi.Var component_ind(3*x <= 4*z,) (value 0.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 3*y - 9*z, y - 3*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(x <= 3*y - 9*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 3*z < x, 3*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(y - 3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 2*y - 6*z, y < 7*z) (value -0.0)>,
#  <gurobi.Var component_ind(x <= 2*y - 6*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 7*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= -y + 7*z, 3*z < y, 3*z < y) (value -0.0)>,
#  <gurobi.Var component_ind(x <= -y + 7*z,) (value -0.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(4*z < x, 3*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(4*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= 12*z, 4*z < x, 3*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(x <= 12*z,) (value 1.0)>,
#  <gurobi.Var component_ind(4*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var single_ind(x <= y - 7*z,) (value -0.0)>,
#  <gurobi.Var main_ind(x <= 8*z, 7*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(x <= 8*z,) (value 1.0)>,
#  <gurobi.Var component_ind(7*z < y,) (value 1.0)>,
#  <gurobi.Var single_ind(7*y <= 9*x,) (value 1.0)>,
#  <gurobi.Var single_ind(4*y - z <= 4*x,) (value -0.0)>,
#  <gurobi.Var main_ind(5*y <= 7*x, 2*y - z < 2*x) (value 0.0)>,
#  <gurobi.Var component_ind(5*y <= 7*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*y - z < 2*x,) (value 0.0)>,
#  <gurobi.Var single_ind(6*y - z <= 6*x,) (value -0.0)>,
#  <gurobi.Var main_ind(5*y <= 11*x, 5*x < 3*y) (value 0.0)>,
#  <gurobi.Var component_ind(5*y <= 11*x,) (value 1.0)>,
#  <gurobi.Var component_ind(5*x < 3*y,) (value 0.0)>,
#  <gurobi.Var main_ind(3*y - z <= 5*x, 5*x < 3*y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - z <= 5*x,) (value 1.0)>,
#  <gurobi.Var component_ind(5*x < 3*y,) (value 0.0)>,
#  <gurobi.Var main_ind(3*y - z <= 5*x, 2*x < 2*y - z) (value 1.0)>,
#  <gurobi.Var component_ind(3*y - z <= 5*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*x < 2*y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(2*y - 3*z <= 2*x, 2*x < 2*y - z) (value 1.0)>,
#  <gurobi.Var component_ind(2*y - 3*z <= 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*x < 2*y - z,) (value 1.0)>,
#  <gurobi.Var single_ind(3*y + z <= 5*x,) (value 1.0)>,
#  <gurobi.Var single_ind(y - z <= x,) (value -0.0)>,
#  <gurobi.Var main_ind(3*y <= 4*x, y - z < x) (value 0.0)>,
#  <gurobi.Var component_ind(3*y <= 4*x,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var single_ind(5*y - z <= 5*x,) (value -0.0)>,
#  <gurobi.Var main_ind(2*y <= 3*x, 3*y - z < 3*x) (value 0.0)>,
#  <gurobi.Var component_ind(2*y <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*y - z < 3*x,) (value 0.0)>,
#  <gurobi.Var single_ind(7*y - z <= 7*x,) (value -0.0)>,
#  <gurobi.Var main_ind(3*y - z <= 5*x, 3*x < 3*y - z, y - z < x) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - z <= 5*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < 3*y - z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var main_ind(5*y - 3*z <= 5*x, 3*x < 3*y - z) (value 0.0)>,
#  <gurobi.Var component_ind(5*y - 3*z <= 5*x,) (value 0.0)>,
#  <gurobi.Var component_ind(3*x < 3*y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y + z <= 3*x, y - z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y + z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var single_ind(2*y - z <= 2*x,) (value -0.0)>,
#  <gurobi.Var main_ind(3*y <= 13*x, 3*x < y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y <= 13*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y,) (value 0.0)>,
#  <gurobi.Var main_ind(2*y - z <= 6*x, 3*x < y) (value 0.0)>,
#  <gurobi.Var component_ind(2*y - z <= 6*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y,) (value 0.0)>,
#  <gurobi.Var main_ind(y <= 5*x, 3*x < y, y - z < 3*x) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 5*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y,) (value 0.0)>,
#  <gurobi.Var component_ind(y - z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y - z <= 9*x, 3*x < y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - z <= 9*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y,) (value 0.0)>,
#  <gurobi.Var main_ind(y <= 15*x, 7*x < y) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 15*x,) (value 1.0)>,
#  <gurobi.Var component_ind(7*x < y,) (value 0.0)>,
#  <gurobi.Var main_ind(y - z <= 7*x, 7*x < y) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= 7*x,) (value 1.0)>,
#  <gurobi.Var component_ind(7*x < y,) (value 0.0)>,
#  <gurobi.Var main_ind(y - z <= 7*x, 3*x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= 7*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y - z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 3*z <= 3*x, 3*x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y - z,) (value 0.0)>,
#  <gurobi.Var main_ind(y + z <= 7*x, 3*x < y) (value 0.0)>,
#  <gurobi.Var component_ind(y + z <= 7*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 2*z <= 3*x, 3*x < y) (value 0.0)>,
#  <gurobi.Var component_ind(y - 2*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y,) (value 0.0)>,
#  <gurobi.Var main_ind(3*y - 3*z <= 5*x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(3*y - 3*z <= 5*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 2*z <= x, x < y - z, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y - 2*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - z <= 2*x, x < y - z, y - 3*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y - z <= 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y - 5*z <= 3*x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(3*y - 5*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - z <= 7*x, 3*x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= 7*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y - z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 3*z <= 3*x, 3*x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y - z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 3*z <= 3*x, x < y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 7*z <= x, x < y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 7*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y + z <= 3*x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y + z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 5*z <= x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y - 5*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var single_ind(3*y + z <= 5*x,) (value 1.0)>,
#  <gurobi.Var single_ind(y - z <= x,) (value 0.0)>,
#  <gurobi.Var main_ind(2*y + z <= 4*x, y - 2*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(2*y + z <= 4*x,) (value 1.0)>,
#  <gurobi.Var component_ind(y - 2*z < x,) (value 1.0)>,
#  <gurobi.Var single_ind(3*y - 2*z <= 3*x,) (value -0.0)>,
#  <gurobi.Var main_ind(y + 3*z <= 7*x, 3*x < y + z) (value 0.0)>,
#  <gurobi.Var component_ind(y + 3*z <= 7*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y + z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - z <= 3*x, 3*x < y + z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y + z,) (value 0.0)>,
#  <gurobi.Var main_ind(y + 2*z <= 5*x, 2*x < 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + 2*z <= 5*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*x < 3*z,) (value 0.0)>,
#  <gurobi.Var single_ind(x <= -y + 3*z,) (value -0.0)>,
#  <gurobi.Var main_ind(y - z <= 3*x, x < y - 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - 2*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 6*z <= x, x < y - 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 6*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - 2*z,) (value 0.0)>,
#  <gurobi.Var single_ind(y + 3*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 4*z <= x, 3*z < 2*x) (value 1.0)>,
#  <gurobi.Var component_ind(y - 4*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < 2*x,) (value 1.0)>,
#  <gurobi.Var single_ind(7*y - 7*z <= x,) (value -0.0)>,
#  <gurobi.Var main_ind(2*y <= 3*z, 3*y - 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(2*y <= 3*z,) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - 3*z < x,) (value 0.0)>,
#  <gurobi.Var single_ind(5*y - 5*z <= x,) (value -0.0)>,
#  <gurobi.Var single_ind(3*y <= 4*z,) (value -0.0)>,
#  <gurobi.Var main_ind(5*y - 5*z <= 3*x, x < 3*y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(5*y - 5*z <= 3*x,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 3*y - 3*z,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y - 5*z <= x, x < 3*y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - 5*z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 3*y - 3*z,) (value 1.0)>,
#  <gurobi.Var single_ind(2*y - 2*z <= x,) (value -0.0)>,
#  <gurobi.Var single_ind(x <= -y + 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(3*y - 5*z <= x, 2*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - 5*z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 4*z, 2*z < y, y - z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 4*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var single_ind(6*y - 6*z <= x,) (value -0.0)>,
#  <gurobi.Var single_ind(5*y <= 7*z,) (value -0.0)>,
#  <gurobi.Var single_ind(4*y - 4*z <= x,) (value -0.0)>,
#  <gurobi.Var single_ind(7*y <= 9*z,) (value -0.0)>,
#  <gurobi.Var main_ind(2*y - 2*z <= 3*x, x < 2*y - 2*z, y < 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(2*y - 2*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 2*y - 2*z,) (value 1.0)>,
#  <gurobi.Var component_ind(y < 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(3*y - 5*z <= x, x < 2*y - 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - 5*z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 2*y - 2*z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - z <= x, x < -y + 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(x < -y + 3*z,) (value 0.0)>,
#  <gurobi.Var single_ind(x <= -3*y + 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*y - 5*z <= x, 5*z < 3*y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - 5*z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(5*z < 3*y,) (value 1.0)>,
#  <gurobi.Var main_ind(5*y <= 11*z, 5*z < 3*y) (value 0.0)>,
#  <gurobi.Var component_ind(5*y <= 11*z,) (value 0.0)>,
#  <gurobi.Var component_ind(5*z < 3*y,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 2*z, -y + 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 2*z,) (value 0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y - 3*z <= 5*x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(3*y - 3*z <= 5*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 2*z <= x, x < y - z, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y - 2*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - z <= 2*x, x < y - z, y - 3*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y - z <= 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var component_ind(y - 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y - 5*z <= 3*x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(3*y - 5*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - z <= 7*x, 3*x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= 7*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y - z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 3*z <= 3*x, 3*x < y - z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y - z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 3*z <= 3*x, x < y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 7*z <= x, x < y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 7*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y + z <= 3*x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y + z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 5*z <= x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y - 5*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y - 3*z <= 2*x, x < 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - 3*z <= 2*x,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value 0.0)>,
#  <gurobi.Var single_ind(x <= -2*y + 4*z,) (value -0.0)>,
#  <gurobi.Var main_ind(y - z <= x, x < -y + 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(x < -y + 3*z,) (value 0.0)>,
#  <gurobi.Var single_ind(x <= -3*y + 5*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - z <= 6*x, 2*x < y - z, x < 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= 6*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*x < y - z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 3*z <= x, 2*x < y - z, x < 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*x < y - z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 3*z <= x, -y + 3*z < x, x < 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value 0.0)>,
#  <gurobi.Var main_ind(3*x <= -y + 7*z, -y + 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(3*x <= -y + 7*z,) (value 0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y + z <= 3*x, x < 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value 0.0)>,
#  <gurobi.Var single_ind(2*x <= -y + 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(3*y - 9*z <= x, 3*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - 9*z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 5*z, 3*z < y, y - 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 5*z,) (value 0.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(y - 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(2*y - 6*z <= x, 3*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(2*y - 6*z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y <= 13*z, 3*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y <= 13*z,) (value 0.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 3*z <= 3*x, x < y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 7*z <= x, x < y - 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 7*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - 3*z <= 2*x, 3*z < y, x < 4*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - 3*z <= 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 4*z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= -y + 7*z, 3*z < y, 3*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(x <= -y + 7*z,) (value 0.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 7*z <= x, 7*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(y - 7*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(7*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 15*z, 7*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(y <= 15*z,) (value 1.0)>,
#  <gurobi.Var component_ind(7*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 11*z, 3*z < y, 4*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y <= 11*z,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(4*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y <= 7*z, 2*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(3*y <= 7*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var single_ind(y + 5*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 3*z <= x, 2*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y - 3*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y + 3*z <= 2*x, x < 6*z) (value 1.0)>,
#  <gurobi.Var component_ind(y + 3*z <= 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 6*z,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= -y + 7*z, 2*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(x <= -y + 7*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 3*z <= x, 5*z < y, 2*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y - 3*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(5*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 13*z, 5*z < y, 2*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y <= 13*z,) (value 1.0)>,
#  <gurobi.Var component_ind(5*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 9*z, 6*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 9*z,) (value 1.0)>,
#  <gurobi.Var component_ind(6*z < x,) (value 0.0)>,
#  <gurobi.Var single_ind(5*y <= 6*z,) (value -0.0)>,
#  <gurobi.Var single_ind(3*y + 5*z <= 5*x,) (value 1.0)>,
#  <gurobi.Var main_ind(y + 2*z <= 2*x, y - z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y + 2*z <= 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var main_ind(y + 7*z <= 7*x, 3*x < y + 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + 7*z <= 7*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y + 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y + z <= 3*x, 3*x < y + 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < y + 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y + 5*z <= 5*x, x < 2*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + 5*z <= 5*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 2*z,) (value 0.0)>,
#  <gurobi.Var single_ind(x <= -y + 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y + z <= 3*x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y + z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 5*z <= x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y - 5*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var single_ind(y + 5*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 3*z <= x, 2*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y - 3*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y + 6*z <= 6*x, 2*x < y + 2*z, x < 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + 6*z <= 6*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*x < y + 2*z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y - z <= x, 2*x < y + 2*z, x < 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(2*x < y + 2*z,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(y + 4*z <= 4*x, 3*x < 5*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + 4*z <= 4*x,) (value 1.0)>,
#  <gurobi.Var component_ind(3*x < 5*z,) (value 0.0)>,
#  <gurobi.Var single_ind(3*x <= -y + 5*z,) (value -0.0)>,
#  <gurobi.Var main_ind(y - z <= x, -y + 3*z < x, x < 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(3*x <= -y + 9*z, -y + 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(3*x <= -y + 9*z,) (value 0.0)>,
#  <gurobi.Var component_ind(-y + 3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y + 5*z <= 3*x, x < 3*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + 5*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 3*z,) (value 0.0)>,
#  <gurobi.Var main_ind(2*x <= -y + 6*z, 5*z < 3*x) (value 0.0)>,
#  <gurobi.Var component_ind(2*x <= -y + 6*z,) (value 0.0)>,
#  <gurobi.Var component_ind(5*z < 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y - 5*z <= x, 2*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y - 5*z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 4*z, 2*z < y, y - z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 4*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(y - z < x,) (value 0.0)>,
#  <gurobi.Var main_ind(2*y - 3*z <= x, 2*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(2*y - 3*z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(3*y <= 10*z, 2*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(3*y <= 10*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y + z <= 3*x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y + z <= 3*x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 5*z <= x, x < y - z) (value 1.0)>,
#  <gurobi.Var component_ind(y - 5*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(x < y - z,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 2*x, 2*z < y, x < 5*z) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 2*x,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(x < 5*z,) (value 0.0)>,
#  <gurobi.Var main_ind(x <= -y + 7*z, 2*z < y) (value 0.0)>,
#  <gurobi.Var component_ind(x <= -y + 7*z,) (value 0.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y - 5*z <= x, 6*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(y - 5*z <= x,) (value 1.0)>,
#  <gurobi.Var component_ind(6*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 14*z, 6*z < y) (value 1.0)>,
#  <gurobi.Var component_ind(y <= 14*z,) (value 1.0)>,
#  <gurobi.Var component_ind(6*z < y,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 10*z, 2*z < y, 5*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y <= 10*z,) (value 1.0)>,
#  <gurobi.Var component_ind(2*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(5*z < x,) (value 1.0)>,
#  <gurobi.Var single_ind(y + 9*z <= 3*x,) (value 1.0)>,
#  <gurobi.Var main_ind(y - z <= x, 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y + 6*z <= 2*x, x < 7*z) (value 0.0)>,
#  <gurobi.Var component_ind(y + 6*z <= 2*x,) (value 0.0)>,
#  <gurobi.Var component_ind(x < 7*z,) (value 1.0)>,
#  <gurobi.Var main_ind(x <= -y + 7*z, 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(x <= -y + 7*z,) (value 0.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y - z <= x, 4*z < y, 3*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y - z <= x,) (value 0.0)>,
#  <gurobi.Var component_ind(4*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 12*z, 4*z < y, 3*z < x) (value 1.0)>,
#  <gurobi.Var component_ind(y <= 12*z,) (value 1.0)>,
#  <gurobi.Var component_ind(4*z < y,) (value 1.0)>,
#  <gurobi.Var component_ind(3*z < x,) (value 1.0)>,
#  <gurobi.Var main_ind(y <= 8*z, 7*z < x) (value 0.0)>,
#  <gurobi.Var component_ind(y <= 8*z,) (value 1.0)>,
#  <gurobi.Var component_ind(7*z < x,) (value 0.0)>]
